# %%
from docplex.cp.model import *
from docplex.cp.config import get_default
import random

# %%
from config import setup
setup()

# %%
#UTILS  : 
#Données d'entrée :
#H,F liste des agents
#L[I] préférences de l'agent I

def create_random_problem(n):
    F = []
    H = []
    for i in range(1,n+1):
        F.append('f'+str(i))
        H.append('h'+str(i))

    L= {}
    for f in F:
        pref = list(H)
        random.shuffle(pref)
        L[f]=pref
    for h in H:
        pref = list(F)
        random.shuffle(pref)
        L[h]=pref
    
    return  F, H, L

# %% [markdown]
# 1. Proposez un modèle de programmation par contrainte pour trouver un mariage stable. Le modèle peut inclure
# des contraintes logiques (par exemple if_then). L’utilisation de ce genre de contraintes est accessible dans la
# documentation du solveur. Utilisez la recherche en profondeur par défaut ((’DepthFirst’) sans préciser des
# heuristiques de branchements. N’affichez pas les traces d’exécutions internes du solveur

# %%
def simple_stable_mariage(mdl, F, H, L):
    #Lpos[i,j] postition de j dans L(i) (facilite le traitement)
    def preprocess(H,F,L):
        LPos = {}
        for h in H:
            for f in F:
                LPos[h,f]=L[h].index(f)
                LPos[f,h]=L[f].index(h)
        return LPos
    
    LPos = preprocess(H,F,L) 
    #x[h,f] mariage entre h et f
    x = {}
    for h in H:
        for f in F:
            x[h,f]=mdl.binary_var(name="x_" + h + "_" + f)

    #D[i] cout du marriage de i (Position de son partenaire dans L(i))
    D = {}
    for i in H+F:
        D[i]=mdl.integer_var(name="D_"+i)


    #Ajout des contraintes
    #Contrainte de monogamie :
    for h in H:
        mdl.add(sum([x[h,f] for f in F])==1)
    for f in F:
        mdl.add(sum([x[h,f] for h in H])==1)


    #Valeur de D (Position du partenaire dans le classement) :
    for h in H:
        mdl.add(D[h]==sum([(x[h,f]*LPos[h,f]) for f in F]))
    for f in F:
        mdl.add(D[f]==sum([(x[h,f]*LPos[f,h]) for h in H]))

    #Couple bloquant =
    #(h,f) est un couple bloquant si 
    #   - le partenaire actuel de h et en plus haute postion de preference que f
    #   - et le partenaire actuel de f et en plus haute postion de preference que h
    for h in H:
        for f in F:
            mdl.add(((D[h]>LPos[h,f]) & (D[f]>LPos[f,h]))==false())

    return x, D

# %%
def print_solution(solution,x,D):
    print("\n   SOLUTION :\n")
    for h in H:
        for f in F:
            if(solution[x[h,f]]==1):
                print("Mariage entre ",h," et ",f," (Couts = ",solution[D[h]],solution[D[f]],")")

# %% [markdown]
# 2. Testez le modèle avec l’exemple ci-dessus (ou un autre exemple) en affichant toutes les solutions. Affichez chaque
# solution avec un format que vous jugez compréhensible

# %%
mdl = CpoModel(name="Mariages")

F = ['f1', 'f2', 'f3', 'f4', 'f5', 'f6']
H = ['h1', 'h2', 'h3', 'h4', 'h5', 'h6']

L= {'h1': ['f1', 'f3', 'f6', 'f2', 'f4', 'f5'],
    'h2': ['f4', 'f6', 'f1', 'f2', 'f5', 'f3'],
    'h3': ['f1', 'f4', 'f5', 'f3', 'f6', 'f2'],
    'h4': ['f6', 'f5', 'f3', 'f4', 'f2', 'f1'],
    'h5': ['f2', 'f3', 'f1', 'f4', 'f5', 'f6'],
    'h6': ['f3', 'f1', 'f2', 'f6', 'f5', 'f4'],
    'f1': ['h1', 'h5', 'h6', 'h3', 'h2', 'h4'],
    'f2': ['h2', 'h4', 'h6', 'h1', 'h3', 'h5'],
    'f3': ['h4', 'h3', 'h6', 'h2', 'h5', 'h1'],
    'f4': ['h1', 'h3', 'h5', 'h4', 'h2', 'h6'],
    'f5': ['h3', 'h2', 'h6', 'h1', 'h4', 'h5'],
    'f6': ['h5', 'h1', 'h3', 'h6', 'h4', 'h2']}

x, D = simple_stable_mariage(mdl,F,H,L)

lsol = mdl.start_search(SearchType="DepthFirst",trace_log=False)

for solution in lsol:
    print_solution(solution,x,D)
# Out:
#    SOLUTION :
#
# Mariage entre  h1  et  f1  (Couts =  0 0 )
# Mariage entre  h2  et  f2  (Couts =  3 0 )
# Mariage entre  h3  et  f4  (Couts =  1 1 )
# Mariage entre  h4  et  f6  (Couts =  0 4 )
# Mariage entre  h5  et  f5  (Couts =  4 5 )
# Mariage entre  h6  et  f3  (Couts =  0 2 )
#
#    SOLUTION :
#
# Mariage entre  h1  et  f1  (Couts =  0 0 )
# Mariage entre  h2  et  f2  (Couts =  3 0 )
# Mariage entre  h3  et  f4  (Couts =  1 1 )
# Mariage entre  h4  et  f3  (Couts =  2 0 )
# Mariage entre  h5  et  f6  (Couts =  5 0 )
# Mariage entre  h6  et  f5  (Couts =  4 2 )
#
#    SOLUTION :
#
# Mariage entre  h1  et  f1  (Couts =  0 0 )
# Mariage entre  h2  et  f2  (Couts =  3 0 )
# Mariage entre  h3  et  f4  (Couts =  1 1 )
# Mariage entre  h4  et  f5  (Couts =  1 4 )
# Mariage entre  h5  et  f6  (Couts =  5 0 )
# Mariage entre  h6  et  f3  (Couts =  0 2 )

# %% [markdown]
# 3. Proposez deux stratégies de recherches différentes qui vous semblent très différentes (i.e., deux combinaisons
# de type <heuristique de choix de variables + heuristique de choix de valeurs>). On note ces deux stratégies
# par S1 et S2

# %%
vars = [i for i in x.values()]+[i for i in D.values()]
strats = {}
strats["S1"] = mdl.search_phase(vars,varchooser=mdl.select_random_var(), valuechooser=mdl.select_smallest(value()))
strats["S2"] = mdl.search_phase(vars,varchooser=mdl.select_random_var(), valuechooser=mdl.select_random_value())

# %% [markdown]
# On veut tester S1 et S2 avec une recherche en profondeur sans et avec redémarrage (’DepthFirst’ vs ’Restart’). Voici le protocole de l’étude expérimentale :
# * Générez différentes instances randomisées du problème avec différentes tailles (à partir de n = 5). Pour
# chaque taille, générez 5 instances.

# %%
instances = {}   
#sizes = [5,10,20,30]
sizes = [5,10,15,20,25,30]
for N in  sizes:
    for I in  range(0,5):
        instances[N,I] = create_random_problem(N)

# %% [markdown]
# * Lancez les 4 expérimentations (S1 et S2 avec une recherche en profondeur sans et avec redémarrage) avec
# vos jeux de données. Fixez le temps limite à 200s pour chaque exécution 1.

# %%
import matplotlib.pyplot as plt
 
def run(S,type,F,H,L):
    mdl = CpoModel(name="Mariages "+type+" "+S)
    mdl.set_search_phases(strats[S])
    x, D = simple_stable_mariage(mdl,F,H,L)
    solution = mdl.solve(SearchType=type,trace_log=False,TimeLimit=200)
    return (solution.get_solver_infos()['NumberOfChoicePoints'],
    solution.get_solver_infos()['TotalTime'])

#On va dabord choisir les recherches en DepthFirst puis les restart afin de mieux analyser les différentes stratégies (les ecarts étant trop grands)
fig, axs = plt.subplots(5, 2, figsize=(16,16))
lines = {}
for I in range(0,5):
    for strat, type, color in zip(["S1","S2","S1","S2"],["DepthFirst","DepthFirst","Restart","Restart"],["b","r","g","y"]):    
        results_time = []
        results_noeuds = []
        for N in sizes:
            print("Instance",I,"strat",strat,type,"[Taille =",N,"]")
            noeuds, temps = run(strat,type,*instances[N,I])
            results_time.append(temps)
            results_noeuds.append(noeuds)
        lines[color],=axs[I][0].plot(sizes, results_time, color)
        axs[I][1].plot(sizes, results_noeuds, color)
    axs[I][0].set_ylabel("temps")
    axs[I][1].set_ylabel("noeuds")
    axs[I][0].set_title("Instance "+str(I)+" (temps)")
    axs[I][1].set_title("Instance "+str(I)+" (noeuds)")

plt.figlegend([lines['b'],lines['r'],lines['g'],lines['g']],["S1 + DepthFirst","S2 + DepthFirst","S1 + Restart","S2 + Restart"],loc = 'lower center')
# Out:
# Instance 0 strat S1 DepthFirst [Taille = 5 ]
# Instance 0 strat S1 DepthFirst [Taille = 10 ]
# Instance 0 strat S1 DepthFirst [Taille = 15 ]
# Instance 0 strat S1 DepthFirst [Taille = 20 ]
# Instance 0 strat S1 DepthFirst [Taille = 25 ]
# Instance 0 strat S1 DepthFirst [Taille = 30 ]
# Instance 0 strat S2 DepthFirst [Taille = 5 ]
# Instance 0 strat S2 DepthFirst [Taille = 10 ]
# Instance 0 strat S2 DepthFirst [Taille = 15 ]
# Instance 0 strat S2 DepthFirst [Taille = 20 ]
# Instance 0 strat S2 DepthFirst [Taille = 25 ]
# Instance 0 strat S2 DepthFirst [Taille = 30 ]
# Instance 0 strat S1 Restart [Taille = 5 ]
# Instance 0 strat S1 Restart [Taille = 10 ]
# Instance 0 strat S1 Restart [Taille = 15 ]
# Instance 0 strat S1 Restart [Taille = 20 ]
# Instance 0 strat S1 Restart [Taille = 25 ]
# Instance 0 strat S1 Restart [Taille = 30 ]
# Instance 0 strat S2 Restart [Taille = 5 ]
# Instance 0 strat S2 Restart [Taille = 10 ]
# Instance 0 strat S2 Restart [Taille = 15 ]
# Instance 0 strat S2 Restart [Taille = 20 ]
# Instance 0 strat S2 Restart [Taille = 25 ]
# Instance 0 strat S2 Restart [Taille = 30 ]
# Instance 1 strat S1 DepthFirst [Taille = 5 ]
# Instance 1 strat S1 DepthFirst [Taille = 10 ]
# Instance 1 strat S1 DepthFirst [Taille = 15 ]
# Instance 1 strat S1 DepthFirst [Taille = 20 ]
# Instance 1 strat S1 DepthFirst [Taille = 25 ]
# Instance 1 strat S1 DepthFirst [Taille = 30 ]
# Instance 1 strat S2 DepthFirst [Taille = 5 ]
# Instance 1 strat S2 DepthFirst [Taille = 10 ]
# Instance 1 strat S2 DepthFirst [Taille = 15 ]
# Instance 1 strat S2 DepthFirst [Taille = 20 ]
# Instance 1 strat S2 DepthFirst [Taille = 25 ]
# Instance 1 strat S2 DepthFirst [Taille = 30 ]
# Instance 1 strat S1 Restart [Taille = 5 ]
# Instance 1 strat S1 Restart [Taille = 10 ]
# Instance 1 strat S1 Restart [Taille = 15 ]
# Instance 1 strat S1 Restart [Taille = 20 ]
# Instance 1 strat S1 Restart [Taille = 25 ]
# Instance 1 strat S1 Restart [Taille = 30 ]
# Instance 1 strat S2 Restart [Taille = 5 ]
# Instance 1 strat S2 Restart [Taille = 10 ]
# Instance 1 strat S2 Restart [Taille = 15 ]
# Instance 1 strat S2 Restart [Taille = 20 ]
# Instance 1 strat S2 Restart [Taille = 25 ]
# Instance 1 strat S2 Restart [Taille = 30 ]
# Instance 2 strat S1 DepthFirst [Taille = 5 ]
# Instance 2 strat S1 DepthFirst [Taille = 10 ]
# Instance 2 strat S1 DepthFirst [Taille = 15 ]
# Instance 2 strat S1 DepthFirst [Taille = 20 ]
# Instance 2 strat S1 DepthFirst [Taille = 25 ]
# Instance 2 strat S1 DepthFirst [Taille = 30 ]
# Instance 2 strat S2 DepthFirst [Taille = 5 ]
# Instance 2 strat S2 DepthFirst [Taille = 10 ]
# Instance 2 strat S2 DepthFirst [Taille = 15 ]
# Instance 2 strat S2 DepthFirst [Taille = 20 ]
# Instance 2 strat S2 DepthFirst [Taille = 25 ]
# Instance 2 strat S2 DepthFirst [Taille = 30 ]
# Instance 2 strat S1 Restart [Taille = 5 ]
# Instance 2 strat S1 Restart [Taille = 10 ]
# Instance 2 strat S1 Restart [Taille = 15 ]
# Instance 2 strat S1 Restart [Taille = 20 ]
# Instance 2 strat S1 Restart [Taille = 25 ]
# Instance 2 strat S1 Restart [Taille = 30 ]
# Instance 2 strat S2 Restart [Taille = 5 ]
# Instance 2 strat S2 Restart [Taille = 10 ]
# Instance 2 strat S2 Restart [Taille = 15 ]
# Instance 2 strat S2 Restart [Taille = 20 ]
# Instance 2 strat S2 Restart [Taille = 25 ]
# Instance 2 strat S2 Restart [Taille = 30 ]
# Instance 3 strat S1 DepthFirst [Taille = 5 ]
# Instance 3 strat S1 DepthFirst [Taille = 10 ]
# Instance 3 strat S1 DepthFirst [Taille = 15 ]
# Instance 3 strat S1 DepthFirst [Taille = 20 ]
# Instance 3 strat S1 DepthFirst [Taille = 25 ]
# Instance 3 strat S1 DepthFirst [Taille = 30 ]
# Instance 3 strat S2 DepthFirst [Taille = 5 ]
# Instance 3 strat S2 DepthFirst [Taille = 10 ]
# Instance 3 strat S2 DepthFirst [Taille = 15 ]
# Instance 3 strat S2 DepthFirst [Taille = 20 ]
# Instance 3 strat S2 DepthFirst [Taille = 25 ]
# Instance 3 strat S2 DepthFirst [Taille = 30 ]
# Instance 3 strat S1 Restart [Taille = 5 ]
# Instance 3 strat S1 Restart [Taille = 10 ]
# Instance 3 strat S1 Restart [Taille = 15 ]
# Instance 3 strat S1 Restart [Taille = 20 ]
# Instance 3 strat S1 Restart [Taille = 25 ]
# Instance 3 strat S1 Restart [Taille = 30 ]
# Instance 3 strat S2 Restart [Taille = 5 ]
# Instance 3 strat S2 Restart [Taille = 10 ]
# Instance 3 strat S2 Restart [Taille = 15 ]
# Instance 3 strat S2 Restart [Taille = 20 ]
# Instance 3 strat S2 Restart [Taille = 25 ]
# Instance 3 strat S2 Restart [Taille = 30 ]
# Instance 4 strat S1 DepthFirst [Taille = 5 ]
# Instance 4 strat S1 DepthFirst [Taille = 10 ]
# Instance 4 strat S1 DepthFirst [Taille = 15 ]
# Instance 4 strat S1 DepthFirst [Taille = 20 ]
# Instance 4 strat S1 DepthFirst [Taille = 25 ]
# Instance 4 strat S1 DepthFirst [Taille = 30 ]
# Instance 4 strat S2 DepthFirst [Taille = 5 ]
# Instance 4 strat S2 DepthFirst [Taille = 10 ]
# Instance 4 strat S2 DepthFirst [Taille = 15 ]
# Instance 4 strat S2 DepthFirst [Taille = 20 ]
# Instance 4 strat S2 DepthFirst [Taille = 25 ]
# Instance 4 strat S2 DepthFirst [Taille = 30 ]
# Instance 4 strat S1 Restart [Taille = 5 ]
# Instance 4 strat S1 Restart [Taille = 10 ]
# Instance 4 strat S1 Restart [Taille = 15 ]
# Instance 4 strat S1 Restart [Taille = 20 ]
# Instance 4 strat S1 Restart [Taille = 25 ]
# Instance 4 strat S1 Restart [Taille = 30 ]
# Instance 4 strat S2 Restart [Taille = 5 ]
# Instance 4 strat S2 Restart [Taille = 10 ]
# Instance 4 strat S2 Restart [Taille = 15 ]
# Instance 4 strat S2 Restart [Taille = 20 ]
# Instance 4 strat S2 Restart [Taille = 25 ]
# Instance 4 strat S2 Restart [Taille = 30 ]

# %%
for strat, type, color in zip(["S1","S2","S1","S2"],["DepthFirst","DepthFirst","Restart","Restart"],["b","r","g","y"]):
    print(strat,type,color)
# Out:
# S1 DepthFirst b
# S2 DepthFirst r
# S1 Restart g
# S2 Restart y

# %% [markdown]
# * Quelles sont vos conclusions ?

# %%
instances
# Out:
# {(5, 0): (['f1', 'f2', 'f3', 'f4', 'f5'],
#   ['h1', 'h2', 'h3', 'h4', 'h5'],
#   {'f1': ['h3', 'h2', 'h4', 'h5', 'h1'],
#    'f2': ['h3', 'h2', 'h5', 'h1', 'h4'],
#    'f3': ['h1', 'h5', 'h4', 'h2', 'h3'],
#    'f4': ['h2', 'h1', 'h5', 'h4', 'h3'],
#    'f5': ['h4', 'h5', 'h3', 'h2', 'h1'],
#    'h1': ['f4', 'f1', 'f3', 'f5', 'f2'],
#    'h2': ['f1', 'f4', 'f2', 'f5', 'f3'],
#    'h3': ['f2', 'f5', 'f4', 'f3', 'f1'],
#    'h4': ['f1', 'f4', 'f3', 'f2', 'f5'],
#    'h5': ['f2', 'f5', 'f4', 'f3', 'f1']}),
#  (5, 1): (['f1', 'f2', 'f3', 'f4', 'f5'],
#   ['h1', 'h2', 'h3', 'h4', 'h5'],
#   {'f1': ['h4', 'h5', 'h3', 'h2', 'h1'],
#    'f2': ['h3', 'h4', 'h2', 'h5', 'h1'],
#    'f3': ['h4', 'h5', 'h2', 'h3', 'h1'],
#    'f4': ['h2', 'h5', 'h1', 'h3', 'h4'],
#    'f5': ['h5', 'h2', 'h3', 'h1', 'h4'],
#    'h1': ['f1', 'f3', 'f2', 'f4', 'f5'],
#    'h2': ['f4', 'f2', 'f1', 'f5', 'f3'],
#    'h3': ['f1', 'f5', 'f4', 'f3', 'f2'],
#    'h4': ['f4', 'f2', 'f3', 'f5', 'f1'],
#    'h5': ['f4', 'f1', 'f5', 'f2', 'f3']}),
#  (5, 2): (['f1', 'f2', 'f3', 'f4', 'f5'],
#   ['h1', 'h2', 'h3', 'h4', 'h5'],
#   {'f1': ['h1', 'h2', 'h4', 'h3', 'h5'],
#    'f2': ['h3', 'h2', 'h5', 'h4', 'h1'],
#    'f3': ['h5', 'h1', 'h4', 'h3', 'h2'],
#    'f4': ['h3', 'h1', 'h5', 'h4', 'h2'],
#    'f5': ['h4', 'h1', 'h3', 'h2', 'h5'],
#    'h1': ['f4', 'f5', 'f3', 'f2', 'f1'],
#    'h2': ['f1', 'f2', 'f4', 'f3', 'f5'],
#    'h3': ['f3', 'f4', 'f1', 'f5', 'f2'],
#    'h4': ['f1', 'f2', 'f5', 'f4', 'f3'],
#    'h5': ['f2', 'f5', 'f3', 'f4', 'f1']}),
#  (5, 3): (['f1', 'f2', 'f3', 'f4', 'f5'],
#   ['h1', 'h2', 'h3', 'h4', 'h5'],
#   {'f1': ['h5', 'h3', 'h2', 'h4', 'h1'],
#    'f2': ['h2', 'h4', 'h5', 'h1', 'h3'],
#    'f3': ['h5', 'h2', 'h4', 'h3', 'h1'],
#    'f4': ['h4', 'h5', 'h1', 'h2', 'h3'],
#    'f5': ['h1', 'h5', 'h3', 'h4', 'h2'],
#    'h1': ['f5', 'f4', 'f2', 'f3', 'f1'],
#    'h2': ['f1', 'f3', 'f4', 'f5', 'f2'],
#    'h3': ['f2', 'f1', 'f5', 'f4', 'f3'],
#    'h4': ['f3', 'f2', 'f4', 'f1', 'f5'],
#    'h5': ['f5', 'f3', 'f4', 'f1', 'f2']}),
#  (5, 4): (['f1', 'f2', 'f3', 'f4', 'f5'],
#   ['h1', 'h2', 'h3', 'h4', 'h5'],
#   {'f1': ['h4', 'h2', 'h1', 'h3', 'h5'],
#    'f2': ['h3', 'h2', 'h5', 'h4', 'h1'],
#    'f3': ['h2', 'h3', 'h1', 'h4', 'h5'],
#    'f4': ['h3', 'h4', 'h5', 'h1', 'h2'],
#    'f5': ['h3', 'h1', 'h5', 'h4', 'h2'],
#    'h1': ['f3', 'f5', 'f4', 'f1', 'f2'],
#    'h2': ['f5', 'f4', 'f2', 'f3', 'f1'],
#    'h3': ['f3', 'f1', 'f5', 'f4', 'f2'],
#    'h4': ['f1', 'f5', 'f2', 'f4', 'f3'],
#    'h5': ['f3', 'f2', 'f1', 'f4', 'f5']}),
#  (10, 0): (['f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10'],
#   ['h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'h7', 'h8', 'h9', 'h10'],
#   {'f1': ['h6', 'h9', 'h5', 'h2', 'h3', 'h10', 'h7', 'h4', 'h8', 'h1'],
#    'f2': ['h2', 'h9', 'h4', 'h7', 'h1', 'h8', 'h6', 'h10', 'h3', 'h5'],
#    'f3': ['h6', 'h4', 'h10', 'h9', 'h1', 'h7', 'h2', 'h5', 'h3', 'h8'],
#    'f4': ['h2', 'h1', 'h6', 'h4', 'h10', 'h9', 'h8', 'h5', 'h7', 'h3'],
#    'f5': ['h5', 'h9', 'h8', 'h2', 'h6', 'h10', 'h4', 'h3', 'h7', 'h1'],
#    'f6': ['h6', 'h3', 'h9', 'h5', 'h2', 'h7', 'h1', 'h4', 'h10', 'h8'],
#    'f7': ['h1', 'h10', 'h5', 'h8', 'h4', 'h7', 'h6', 'h2', 'h3', 'h9'],
#    'f8': ['h4', 'h2', 'h1', 'h9', 'h3', 'h8', 'h10', 'h7', 'h5', 'h6'],
#    'f9': ['h6', 'h7', 'h8', 'h4', 'h3', 'h2', 'h10', 'h9', 'h5', 'h1'],
#    'f10': ['h1', 'h4', 'h3', 'h7', 'h10', 'h2', 'h8', 'h9', 'h6', 'h5'],
#    'h1': ['f2', 'f6', 'f10', 'f8', 'f3', 'f1', 'f5', 'f4', 'f9', 'f7'],
#    'h2': ['f10', 'f2', 'f5', 'f8', 'f1', 'f6', 'f9', 'f7', 'f3', 'f4'],
#    'h3': ['f8', 'f10', 'f3', 'f6', 'f9', 'f5', 'f2', 'f4', 'f1', 'f7'],
#    'h4': ['f3', 'f9', 'f6', 'f5', 'f8', 'f7', 'f1', 'f4', 'f10', 'f2'],
#    'h5': ['f2', 'f3', 'f8', 'f10', 'f7', 'f9', 'f4', 'f1', 'f6', 'f5'],
#    'h6': ['f3', 'f4', 'f9', 'f7', 'f8', 'f6', 'f2', 'f10', 'f5', 'f1'],
#    'h7': ['f8', 'f1', 'f4', 'f9', 'f5', 'f7', 'f6', 'f10', 'f2', 'f3'],
#    'h8': ['f3', 'f7', 'f9', 'f6', 'f1', 'f5', 'f8', 'f2', 'f10', 'f4'],
#    'h9': ['f10', 'f5', 'f1', 'f6', 'f3', 'f9', 'f2', 'f4', 'f7', 'f8'],
#    'h10': ['f3', 'f5', 'f4', 'f8', 'f7', 'f10', 'f9', 'f6', 'f2', 'f1']}),
#  (10, 1): (['f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10'],
#   ['h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'h7', 'h8', 'h9', 'h10'],
#   {'f1': ['h10', 'h5', 'h2', 'h3', 'h8', 'h7', 'h6', 'h4', 'h9', 'h1'],
#    'f2': ['h1', 'h10', 'h9', 'h8', 'h2', 'h7', 'h4', 'h3', 'h6', 'h5'],
#    'f3': ['h8', 'h5', 'h10', 'h6', 'h2', 'h4', 'h9', 'h7', 'h1', 'h3'],
#    'f4': ['h5', 'h2', 'h6', 'h9', 'h8', 'h10', 'h3', 'h4', 'h1', 'h7'],
#    'f5': ['h6', 'h8', 'h9', 'h4', 'h2', 'h10', 'h3', 'h7', 'h5', 'h1'],
#    'f6': ['h10', 'h1', 'h4', 'h5', 'h7', 'h2', 'h9', 'h8', 'h3', 'h6'],
#    'f7': ['h7', 'h5', 'h9', 'h6', 'h2', 'h1', 'h8', 'h3', 'h10', 'h4'],
#    'f8': ['h10', 'h3', 'h2', 'h1', 'h5', 'h6', 'h7', 'h4', 'h9', 'h8'],
#    'f9': ['h5', 'h7', 'h8', 'h3', 'h1', 'h10', 'h2', 'h4', 'h9', 'h6'],
#    'f10': ['h4', 'h6', 'h10', 'h2', 'h1', 'h5', 'h7', 'h9', 'h3', 'h8'],
#    'h1': ['f1', 'f5', 'f8', 'f10', 'f2', 'f9', 'f7', 'f6', 'f3', 'f4'],
#    'h2': ['f2', 'f8', 'f4', 'f5', 'f3', 'f9', 'f6', 'f10', 'f1', 'f7'],
#    'h3': ['f6', 'f8', 'f2', 'f9', 'f4', 'f10', 'f3', 'f7', 'f1', 'f5'],
#    'h4': ['f4', 'f7', 'f3', 'f6', 'f10', 'f9', 'f5', 'f8', 'f1', 'f2'],
#    'h5': ['f10', 'f2', 'f1', 'f3', 'f8', 'f6', 'f7', 'f5', 'f9', 'f4'],
#    'h6': ['f7', 'f4', 'f10', 'f6', 'f2', 'f8', 'f3', 'f5', 'f1', 'f9'],
#    'h7': ['f1', 'f9', 'f4', 'f3', 'f10', 'f5', 'f7', 'f6', 'f8', 'f2'],
#    'h8': ['f8', 'f6', 'f3', 'f1', 'f7', 'f5', 'f10', 'f9', 'f2', 'f4'],
#    'h9': ['f3', 'f10', 'f4', 'f8', 'f9', 'f1', 'f6', 'f7', 'f2', 'f5'],
#    'h10': ['f9', 'f6', 'f4', 'f10', 'f3', 'f7', 'f5', 'f1', 'f2', 'f8']}),
#  (10, 2): (['f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10'],
#   ['h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'h7', 'h8', 'h9', 'h10'],
#   {'f1': ['h10', 'h1', 'h7', 'h5', 'h8', 'h9', 'h3', 'h6', 'h2', 'h4'],
#    'f2': ['h3', 'h6', 'h1', 'h9', 'h10', 'h4', 'h2', 'h5', 'h7', 'h8'],
#    'f3': ['h6', 'h3', 'h10', 'h4', 'h1', 'h8', 'h5', 'h2', 'h7', 'h9'],
#    'f4': ['h4', 'h9', 'h3', 'h1', 'h2', 'h7', 'h6', 'h10', 'h5', 'h8'],
#    'f5': ['h3', 'h7', 'h6', 'h8', 'h4', 'h2', 'h5', 'h9', 'h1', 'h10'],
#    'f6': ['h6', 'h5', 'h3', 'h7', 'h4', 'h9', 'h8', 'h2', 'h10', 'h1'],
#    'f7': ['h1', 'h3', 'h6', 'h4', 'h2', 'h8', 'h7', 'h5', 'h10', 'h9'],
#    'f8': ['h6', 'h1', 'h7', 'h10', 'h2', 'h9', 'h3', 'h8', 'h4', 'h5'],
#    'f9': ['h6', 'h2', 'h9', 'h10', 'h5', 'h4', 'h8', 'h3', 'h1', 'h7'],
#    'f10': ['h4', 'h7', 'h8', 'h2', 'h5', 'h10', 'h1', 'h9', 'h6', 'h3'],
#    'h1': ['f10', 'f5', 'f3', 'f6', 'f7', 'f9', 'f2', 'f1', 'f8', 'f4'],
#    'h2': ['f5', 'f6', 'f7', 'f8', 'f10', 'f2', 'f1', 'f4', 'f9', 'f3'],
#    'h3': ['f2', 'f6', 'f3', 'f1', 'f8', 'f5', 'f10', 'f7', 'f4', 'f9'],
#    'h4': ['f7', 'f8', 'f5', 'f4', 'f2', 'f1', 'f3', 'f10', 'f9', 'f6'],
#    'h5': ['f1', 'f3', 'f10', 'f9', 'f8', 'f2', 'f6', 'f4', 'f5', 'f7'],
#    'h6': ['f5', 'f1', 'f4', 'f3', 'f8', 'f6', 'f2', 'f9', 'f10', 'f7'],
#    'h7': ['f1', 'f7', 'f3', 'f6', 'f5', 'f9', 'f10', 'f8', 'f4', 'f2'],
#    'h8': ['f1', 'f2', 'f7', 'f10', 'f8', 'f6', 'f3', 'f4', 'f9', 'f5'],
#    'h9': ['f2', 'f6', 'f3', 'f4', 'f9', 'f8', 'f5', 'f10', 'f7', 'f1'],
#    'h10': ['f10', 'f3', 'f9', 'f7', 'f2', 'f5', 'f4', 'f8', 'f6', 'f1']}),
#  (10, 3): (['f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10'],
#   ['h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'h7', 'h8', 'h9', 'h10'],
#   {'f1': ['h8', 'h2', 'h10', 'h7', 'h5', 'h9', 'h3', 'h6', 'h1', 'h4'],
#    'f2': ['h9', 'h6', 'h4', 'h3', 'h8', 'h10', 'h2', 'h5', 'h7', 'h1'],
#    'f3': ['h8', 'h6', 'h4', 'h5', 'h7', 'h9', 'h2', 'h10', 'h1', 'h3'],
#    'f4': ['h5', 'h4', 'h7', 'h9', 'h2', 'h1', 'h6', 'h3', 'h8', 'h10'],
#    'f5': ['h3', 'h5', 'h2', 'h10', 'h8', 'h6', 'h4', 'h7', 'h1', 'h9'],
#    'f6': ['h4', 'h3', 'h7', 'h9', 'h5', 'h10', 'h6', 'h1', 'h2', 'h8'],
#    'f7': ['h8', 'h1', 'h4', 'h6', 'h9', 'h7', 'h3', 'h10', 'h2', 'h5'],
#    'f8': ['h10', 'h1', 'h8', 'h6', 'h9', 'h2', 'h7', 'h3', 'h4', 'h5'],
#    'f9': ['h1', 'h3', 'h6', 'h10', 'h9', 'h8', 'h7', 'h2', 'h4', 'h5'],
#    'f10': ['h3', 'h10', 'h8', 'h5', 'h9', 'h7', 'h2', 'h4', 'h1', 'h6'],
#    'h1': ['f2', 'f8', 'f4', 'f7', 'f10', 'f3', 'f9', 'f5', 'f6', 'f1'],
#    'h2': ['f6', 'f9', 'f4', 'f1', 'f3', 'f2', 'f8', 'f10', 'f5', 'f7'],
#    'h3': ['f4', 'f6', 'f3', 'f7', 'f5', 'f2', 'f8', 'f9', 'f1', 'f10'],
#    'h4': ['f6', 'f3', 'f9', 'f10', 'f8', 'f2', 'f5', 'f7', 'f1', 'f4'],
#    'h5': ['f10', 'f6', 'f3', 'f2', 'f5', 'f1', 'f4', 'f7', 'f8', 'f9'],
#    'h6': ['f7', 'f10', 'f1', 'f6', 'f5', 'f2', 'f4', 'f9', 'f3', 'f8'],
#    'h7': ['f6', 'f7', 'f3', 'f5', 'f9', 'f4', 'f8', 'f10', 'f1', 'f2'],
#    'h8': ['f1', 'f10', 'f5', 'f7', 'f8', 'f2', 'f9', 'f3', 'f4', 'f6'],
#    'h9': ['f4', 'f6', 'f5', 'f10', 'f7', 'f9', 'f1', 'f3', 'f8', 'f2'],
#    'h10': ['f9', 'f5', 'f2', 'f3', 'f6', 'f10', 'f1', 'f8', 'f7', 'f4']}),
#  (10, 4): (['f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10'],
#   ['h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'h7', 'h8', 'h9', 'h10'],
#   {'f1': ['h1', 'h6', 'h2', 'h5', 'h9', 'h4', 'h10', 'h8', 'h7', 'h3'],
#    'f2': ['h8', 'h4', 'h9', 'h3', 'h7', 'h5', 'h10', 'h1', 'h6', 'h2'],
#    'f3': ['h3', 'h9', 'h4', 'h5', 'h2', 'h10', 'h8', 'h6', 'h7', 'h1'],
#    'f4': ['h8', 'h1', 'h4', 'h2', 'h9', 'h3', 'h6', 'h5', 'h10', 'h7'],
#    'f5': ['h1', 'h10', 'h7', 'h4', 'h8', 'h3', 'h9', 'h6', 'h2', 'h5'],
#    'f6': ['h8', 'h9', 'h7', 'h5', 'h1', 'h3', 'h2', 'h6', 'h4', 'h10'],
#    'f7': ['h10', 'h6', 'h8', 'h2', 'h5', 'h3', 'h4', 'h1', 'h7', 'h9'],
#    'f8': ['h8', 'h9', 'h3', 'h6', 'h4', 'h1', 'h7', 'h10', 'h2', 'h5'],
#    'f9': ['h6', 'h4', 'h5', 'h10', 'h1', 'h9', 'h7', 'h2', 'h3', 'h8'],
#    'f10': ['h5', 'h6', 'h1', 'h9', 'h8', 'h10', 'h2', 'h3', 'h4', 'h7'],
#    'h1': ['f1', 'f5', 'f3', 'f6', 'f7', 'f2', 'f10', 'f8', 'f4', 'f9'],
#    'h2': ['f9', 'f8', 'f10', 'f7', 'f6', 'f4', 'f2', 'f3', 'f5', 'f1'],
#    'h3': ['f7', 'f2', 'f1', 'f5', 'f9', 'f8', 'f6', 'f3', 'f10', 'f4'],
#    'h4': ['f3', 'f4', 'f8', 'f1', 'f2', 'f10', 'f7', 'f5', 'f6', 'f9'],
#    'h5': ['f10', 'f5', 'f1', 'f8', 'f6', 'f3', 'f7', 'f2', 'f4', 'f9'],
#    'h6': ['f9', 'f3', 'f1', 'f2', 'f7', 'f6', 'f8', 'f5', 'f4', 'f10'],
#    'h7': ['f2', 'f8', 'f9', 'f10', 'f5', 'f6', 'f7', 'f3', 'f4', 'f1'],
#    'h8': ['f1', 'f7', 'f8', 'f9', 'f10', 'f6', 'f2', 'f3', 'f4', 'f5'],
#    'h9': ['f8', 'f10', 'f4', 'f1', 'f2', 'f6', 'f7', 'f3', 'f9', 'f5'],
#    'h10': ['f2', 'f3', 'f5', 'f9', 'f1', 'f6', 'f7', 'f4', 'f10', 'f8']}),
#  (20,
#   0): (['f1',
#    'f2',
#    'f3',
#    'f4',
#    'f5',
#    'f6',
#    'f7',
#    'f8',
#    'f9',
#    'f10',
#    'f11',
#    'f12',
#    'f13',
#    'f14',
#    'f15',
#    'f16',
#    'f17',
#    'f18',
#    'f19',
#    'f20'], ['h1',
#    'h2',
#    'h3',
#    'h4',
#    'h5',
#    'h6',
#    'h7',
#    'h8',
#    'h9',
#    'h10',
#    'h11',
#    'h12',
#    'h13',
#    'h14',
#    'h15',
#    'h16',
#    'h17',
#    'h18',
#    'h19',
#    'h20'], {'f1': ['h2',
#     'h1',
#     'h20',
#     'h6',
#     'h9',
#     'h18',
#     'h19',
#     'h11',
#     'h17',
#     'h7',
#     'h12',
#     'h5',
#     'h15',
#     'h3',
#     'h8',
#     'h16',
#     'h4',
#     'h14',
#     'h10',
#     'h13'],
#    'f2': ['h5',
#     'h4',
#     'h3',
#     'h12',
#     'h11',
#     'h2',
#     'h20',
#     'h16',
#     'h15',
#     'h9',
#     'h13',
#     'h7',
#     'h17',
#     'h6',
#     'h10',
#     'h8',
#     'h14',
#     'h19',
#     'h1',
#     'h18'],
#    'f3': ['h2',
#     'h20',
#     'h11',
#     'h12',
#     'h7',
#     'h15',
#     'h9',
#     'h6',
#     'h3',
#     'h16',
#     'h1',
#     'h10',
#     'h18',
#     'h4',
#     'h17',
#     'h19',
#     'h8',
#     'h14',
#     'h13',
#     'h5'],
#    'f4': ['h3',
#     'h15',
#     'h11',
#     'h5',
#     'h18',
#     'h10',
#     'h16',
#     'h6',
#     'h14',
#     'h17',
#     'h20',
#     'h8',
#     'h13',
#     'h12',
#     'h1',
#     'h2',
#     'h9',
#     'h7',
#     'h4',
#     'h19'],
#    'f5': ['h2',
#     'h20',
#     'h12',
#     'h5',
#     'h6',
#     'h7',
#     'h18',
#     'h8',
#     'h4',
#     'h16',
#     'h11',
#     'h1',
#     'h3',
#     'h9',
#     'h19',
#     'h14',
#     'h13',
#     'h15',
#     'h10',
#     'h17'],
#    'f6': ['h14',
#     'h18',
#     'h5',
#     'h8',
#     'h9',
#     'h6',
#     'h13',
#     'h15',
#     'h20',
#     'h10',
#     'h7',
#     'h3',
#     'h4',
#     'h12',
#     'h2',
#     'h1',
#     'h17',
#     'h11',
#     'h16',
#     'h19'],
#    'f7': ['h1',
#     'h2',
#     'h10',
#     'h11',
#     'h13',
#     'h3',
#     'h16',
#     'h18',
#     'h5',
#     'h4',
#     'h8',
#     'h9',
#     'h15',
#     'h12',
#     'h19',
#     'h17',
#     'h6',
#     'h14',
#     'h20',
#     'h7'],
#    'f8': ['h18',
#     'h20',
#     'h14',
#     'h9',
#     'h5',
#     'h11',
#     'h10',
#     'h13',
#     'h15',
#     'h4',
#     'h16',
#     'h17',
#     'h3',
#     'h8',
#     'h12',
#     'h19',
#     'h6',
#     'h2',
#     'h7',
#     'h1'],
#    'f9': ['h18',
#     'h12',
#     'h10',
#     'h9',
#     'h1',
#     'h8',
#     'h3',
#     'h16',
#     'h2',
#     'h7',
#     'h15',
#     'h4',
#     'h13',
#     'h11',
#     'h19',
#     'h5',
#     'h17',
#     'h6',
#     'h14',
#     'h20'],
#    'f10': ['h6',
#     'h15',
#     'h1',
#     'h4',
#     'h2',
#     'h17',
#     'h13',
#     'h18',
#     'h20',
#     'h11',
#     'h10',
#     'h8',
#     'h16',
#     'h9',
#     'h5',
#     'h7',
#     'h14',
#     'h3',
#     'h19',
#     'h12'],
#    'f11': ['h8',
#     'h13',
#     'h5',
#     'h1',
#     'h2',
#     'h9',
#     'h4',
#     'h14',
#     'h11',
#     'h7',
#     'h6',
#     'h20',
#     'h17',
#     'h12',
#     'h18',
#     'h3',
#     'h15',
#     'h19',
#     'h16',
#     'h10'],
#    'f12': ['h19',
#     'h14',
#     'h2',
#     'h20',
#     'h7',
#     'h10',
#     'h18',
#     'h1',
#     'h12',
#     'h17',
#     'h16',
#     'h15',
#     'h6',
#     'h3',
#     'h13',
#     'h5',
#     'h9',
#     'h4',
#     'h11',
#     'h8'],
#    'f13': ['h4',
#     'h14',
#     'h11',
#     'h8',
#     'h17',
#     'h18',
#     'h15',
#     'h12',
#     'h7',
#     'h3',
#     'h10',
#     'h19',
#     'h6',
#     'h5',
#     'h20',
#     'h13',
#     'h2',
#     'h16',
#     'h1',
#     'h9'],
#    'f14': ['h11',
#     'h7',
#     'h8',
#     'h18',
#     'h15',
#     'h14',
#     'h6',
#     'h10',
#     'h12',
#     'h3',
#     'h5',
#     'h17',
#     'h4',
#     'h19',
#     'h9',
#     'h13',
#     'h1',
#     'h16',
#     'h20',
#     'h2'],
#    'f15': ['h7',
#     'h2',
#     'h1',
#     'h16',
#     'h15',
#     'h12',
#     'h14',
#     'h8',
#     'h10',
#     'h5',
#     'h17',
#     'h13',
#     'h18',
#     'h11',
#     'h6',
#     'h9',
#     'h4',
#     'h20',
#     'h19',
#     'h3'],
#    'f16': ['h6',
#     'h17',
#     'h11',
#     'h18',
#     'h16',
#     'h3',
#     'h14',
#     'h12',
#     'h20',
#     'h10',
#     'h5',
#     'h2',
#     'h4',
#     'h8',
#     'h19',
#     'h13',
#     'h7',
#     'h9',
#     'h15',
#     'h1'],
#    'f17': ['h14',
#     'h8',
#     'h9',
#     'h20',
#     'h13',
#     'h3',
#     'h12',
#     'h10',
#     'h6',
#     'h2',
#     'h5',
#     'h17',
#     'h18',
#     'h7',
#     'h19',
#     'h11',
#     'h15',
#     'h16',
#     'h4',
#     'h1'],
#    'f18': ['h16',
#     'h8',
#     'h1',
#     'h3',
#     'h9',
#     'h14',
#     'h15',
#     'h2',
#     'h18',
#     'h7',
#     'h11',
#     'h17',
#     'h20',
#     'h6',
#     'h13',
#     'h5',
#     'h19',
#     'h4',
#     'h10',
#     'h12'],
#    'f19': ['h4',
#     'h20',
#     'h8',
#     'h1',
#     'h17',
#     'h5',
#     'h7',
#     'h9',
#     'h12',
#     'h3',
#     'h14',
#     'h10',
#     'h19',
#     'h13',
#     'h6',
#     'h16',
#     'h11',
#     'h15',
#     'h2',
#     'h18'],
#    'f20': ['h3',
#     'h1',
#     'h20',
#     'h17',
#     'h13',
#     'h14',
#     'h19',
#     'h6',
#     'h5',
#     'h9',
#     'h12',
#     'h7',
#     'h16',
#     'h8',
#     'h15',
#     'h10',
#     'h11',
#     'h4',
#     'h18',
#     'h2'],
#    'h1': ['f6',
#     'f13',
#     'f2',
#     'f15',
#     'f4',
#     'f18',
#     'f11',
#     'f7',
#     'f9',
#     'f10',
#     'f12',
#     'f19',
#     'f16',
#     'f8',
#     'f14',
#     'f20',
#     'f5',
#     'f17',
#     'f3',
#     'f1'],
#    'h2': ['f7',
#     'f9',
#     'f10',
#     'f16',
#     'f6',
#     'f14',
#     'f3',
#     'f17',
#     'f1',
#     'f2',
#     'f5',
#     'f8',
#     'f12',
#     'f11',
#     'f18',
#     'f13',
#     'f20',
#     'f15',
#     'f19',
#     'f4'],
#    'h3': ['f7',
#     'f8',
#     'f19',
#     'f4',
#     'f16',
#     'f11',
#     'f15',
#     'f18',
#     'f9',
#     'f13',
#     'f2',
#     'f3',
#     'f1',
#     'f5',
#     'f12',
#     'f14',
#     'f6',
#     'f17',
#     'f10',
#     'f20'],
#    'h4': ['f20',
#     'f5',
#     'f18',
#     'f19',
#     'f2',
#     'f8',
#     'f17',
#     'f3',
#     'f13',
#     'f16',
#     'f1',
#     'f7',
#     'f4',
#     'f15',
#     'f10',
#     'f11',
#     'f6',
#     'f12',
#     'f9',
#     'f14'],
#    'h5': ['f3',
#     'f6',
#     'f14',
#     'f9',
#     'f15',
#     'f2',
#     'f5',
#     'f8',
#     'f1',
#     'f18',
#     'f10',
#     'f4',
#     'f12',
#     'f11',
#     'f17',
#     'f7',
#     'f16',
#     'f19',
#     'f20',
#     'f13'],
#    'h6': ['f20',
#     'f1',
#     'f4',
#     'f8',
#     'f19',
#     'f17',
#     'f18',
#     'f6',
#     'f2',
#     'f13',
#     'f16',
#     'f12',
#     'f15',
#     'f11',
#     'f14',
#     'f9',
#     'f5',
#     'f10',
#     'f3',
#     'f7'],
#    'h7': ['f17',
#     'f13',
#     'f12',
#     'f11',
#     'f6',
#     'f7',
#     'f5',
#     'f19',
#     'f2',
#     'f20',
#     'f18',
#     'f16',
#     'f10',
#     'f4',
#     'f9',
#     'f14',
#     'f15',
#     'f1',
#     'f3',
#     'f8'],
#    'h8': ['f11',
#     'f12',
#     'f15',
#     'f13',
#     'f20',
#     'f10',
#     'f9',
#     'f6',
#     'f14',
#     'f3',
#     'f4',
#     'f18',
#     'f5',
#     'f8',
#     'f1',
#     'f7',
#     'f19',
#     'f17',
#     'f16',
#     'f2'],
#    'h9': ['f13',
#     'f6',
#     'f8',
#     'f11',
#     'f14',
#     'f2',
#     'f7',
#     'f4',
#     'f19',
#     'f9',
#     'f1',
#     'f12',
#     'f17',
#     'f5',
#     'f3',
#     'f18',
#     'f20',
#     'f15',
#     'f10',
#     'f16'],
#    'h10': ['f16',
#     'f4',
#     'f10',
#     'f8',
#     'f14',
#     'f9',
#     'f20',
#     'f3',
#     'f11',
#     'f2',
#     'f12',
#     'f7',
#     'f17',
#     'f19',
#     'f18',
#     'f5',
#     'f15',
#     'f1',
#     'f13',
#     'f6'],
#    'h11': ['f1',
#     'f6',
#     'f12',
#     'f7',
#     'f13',
#     'f2',
#     'f9',
#     'f19',
#     'f4',
#     'f20',
#     'f5',
#     'f3',
#     'f17',
#     'f15',
#     'f10',
#     'f18',
#     'f14',
#     'f11',
#     'f16',
#     'f8'],
#    'h12': ['f16',
#     'f3',
#     'f12',
#     'f6',
#     'f10',
#     'f18',
#     'f11',
#     'f15',
#     'f20',
#     'f4',
#     'f8',
#     'f19',
#     'f5',
#     'f1',
#     'f14',
#     'f7',
#     'f17',
#     'f9',
#     'f2',
#     'f13'],
#    'h13': ['f5',
#     'f19',
#     'f16',
#     'f18',
#     'f10',
#     'f1',
#     'f17',
#     'f15',
#     'f6',
#     'f9',
#     'f11',
#     'f13',
#     'f4',
#     'f12',
#     'f14',
#     'f2',
#     'f20',
#     'f7',
#     'f3',
#     'f8'],
#    'h14': ['f1',
#     'f8',
#     'f9',
#     'f20',
#     'f12',
#     'f4',
#     'f2',
#     'f14',
#     'f19',
#     'f10',
#     'f3',
#     'f17',
#     'f15',
#     'f5',
#     'f13',
#     'f16',
#     'f11',
#     'f18',
#     'f7',
#     'f6'],
#    'h15': ['f14',
#     'f6',
#     'f15',
#     'f2',
#     'f10',
#     'f20',
#     'f18',
#     'f8',
#     'f17',
#     'f9',
#     'f1',
#     'f16',
#     'f5',
#     'f13',
#     'f3',
#     'f7',
#     'f19',
#     'f11',
#     'f4',
#     'f12'],
#    'h16': ['f9',
#     'f5',
#     'f17',
#     'f14',
#     'f20',
#     'f1',
#     'f15',
#     'f6',
#     'f4',
#     'f10',
#     'f12',
#     'f19',
#     'f13',
#     'f3',
#     'f7',
#     'f18',
#     'f16',
#     'f8',
#     'f2',
#     'f11'],
#    'h17': ['f14',
#     'f3',
#     'f11',
#     'f12',
#     'f6',
#     'f10',
#     'f7',
#     'f20',
#     'f17',
#     'f18',
#     'f1',
#     'f16',
#     'f5',
#     'f2',
#     'f15',
#     'f9',
#     'f19',
#     'f4',
#     'f8',
#     'f13'],
#    'h18': ['f4',
#     'f15',
#     'f2',
#     'f19',
#     'f17',
#     'f16',
#     'f1',
#     'f6',
#     'f9',
#     'f14',
#     'f10',
#     'f12',
#     'f18',
#     'f13',
#     'f8',
#     'f7',
#     'f5',
#     'f3',
#     'f20',
#     'f11'],
#    'h19': ['f17',
#     'f5',
#     'f9',
#     'f10',
#     'f2',
#     'f15',
#     'f6',
#     'f1',
#     'f4',
#     'f19',
#     'f16',
#     'f13',
#     'f18',
#     'f3',
#     'f11',
#     'f14',
#     'f20',
#     'f7',
#     'f8',
#     'f12'],
#    'h20': ['f10',
#     'f11',
#     'f1',
#     'f17',
#     'f15',
#     'f7',
#     'f13',
#     'f8',
#     'f2',
#     'f14',
#     'f5',
#     'f6',
#     'f4',
#     'f20',
#     'f19',
#     'f16',
#     'f12',
#     'f18',
#     'f3',
#     'f9']}),
#  (20,
#   1): (['f1',
#    'f2',
#    'f3',
#    'f4',
#    'f5',
#    'f6',
#    'f7',
#    'f8',
#    'f9',
#    'f10',
#    'f11',
#    'f12',
#    'f13',
#    'f14',
#    'f15',
#    'f16',
#    'f17',
#    'f18',
#    'f19',
#    'f20'], ['h1',
#    'h2',
#    'h3',
#    'h4',
#    'h5',
#    'h6',
#    'h7',
#    'h8',
#    'h9',
#    'h10',
#    'h11',
#    'h12',
#    'h13',
#    'h14',
#    'h15',
#    'h16',
#    'h17',
#    'h18',
#    'h19',
#    'h20'], {'f1': ['h3',
#     'h20',
#     'h11',
#     'h16',
#     'h18',
#     'h1',
#     'h15',
#     'h7',
#     'h14',
#     'h4',
#     'h2',
#     'h6',
#     'h12',
#     'h10',
#     'h13',
#     'h17',
#     'h9',
#     'h5',
#     'h19',
#     'h8'],
#    'f2': ['h13',
#     'h16',
#     'h3',
#     'h2',
#     'h4',
#     'h6',
#     'h17',
#     'h1',
#     'h12',
#     'h5',
#     'h15',
#     'h20',
#     'h18',
#     'h14',
#     'h7',
#     'h9',
#     'h10',
#     'h8',
#     'h11',
#     'h19'],
#    'f3': ['h18',
#     'h2',
#     'h20',
#     'h6',
#     'h19',
#     'h10',
#     'h1',
#     'h9',
#     'h15',
#     'h12',
#     'h8',
#     'h3',
#     'h5',
#     'h4',
#     'h14',
#     'h13',
#     'h7',
#     'h11',
#     'h16',
#     'h17'],
#    'f4': ['h11',
#     'h5',
#     'h2',
#     'h17',
#     'h1',
#     'h10',
#     'h7',
#     'h3',
#     'h13',
#     'h20',
#     'h18',
#     'h4',
#     'h8',
#     'h15',
#     'h9',
#     'h19',
#     'h16',
#     'h6',
#     'h12',
#     'h14'],
#    'f5': ['h3',
#     'h16',
#     'h13',
#     'h11',
#     'h15',
#     'h18',
#     'h7',
#     'h6',
#     'h20',
#     'h17',
#     'h5',
#     'h2',
#     'h4',
#     'h12',
#     'h10',
#     'h14',
#     'h8',
#     'h9',
#     'h19',
#     'h1'],
#    'f6': ['h14',
#     'h5',
#     'h15',
#     'h8',
#     'h16',
#     'h19',
#     'h17',
#     'h20',
#     'h18',
#     'h12',
#     'h13',
#     'h4',
#     'h7',
#     'h9',
#     'h3',
#     'h1',
#     'h10',
#     'h2',
#     'h11',
#     'h6'],
#    'f7': ['h4',
#     'h17',
#     'h12',
#     'h11',
#     'h10',
#     'h1',
#     'h6',
#     'h16',
#     'h2',
#     'h15',
#     'h13',
#     'h9',
#     'h20',
#     'h3',
#     'h19',
#     'h14',
#     'h8',
#     'h5',
#     'h18',
#     'h7'],
#    'f8': ['h12',
#     'h4',
#     'h5',
#     'h20',
#     'h19',
#     'h15',
#     'h7',
#     'h1',
#     'h11',
#     'h2',
#     'h10',
#     'h14',
#     'h3',
#     'h17',
#     'h8',
#     'h13',
#     'h9',
#     'h16',
#     'h18',
#     'h6'],
#    'f9': ['h17',
#     'h12',
#     'h6',
#     'h5',
#     'h16',
#     'h2',
#     'h8',
#     'h14',
#     'h1',
#     'h15',
#     'h7',
#     'h19',
#     'h20',
#     'h4',
#     'h13',
#     'h9',
#     'h11',
#     'h3',
#     'h18',
#     'h10'],
#    'f10': ['h16',
#     'h17',
#     'h11',
#     'h9',
#     'h8',
#     'h15',
#     'h13',
#     'h4',
#     'h10',
#     'h19',
#     'h6',
#     'h2',
#     'h5',
#     'h1',
#     'h18',
#     'h3',
#     'h12',
#     'h7',
#     'h20',
#     'h14'],
#    'f11': ['h11',
#     'h15',
#     'h14',
#     'h3',
#     'h4',
#     'h5',
#     'h1',
#     'h17',
#     'h16',
#     'h8',
#     'h18',
#     'h10',
#     'h7',
#     'h19',
#     'h6',
#     'h13',
#     'h12',
#     'h9',
#     'h2',
#     'h20'],
#    'f12': ['h18',
#     'h8',
#     'h17',
#     'h15',
#     'h5',
#     'h6',
#     'h1',
#     'h9',
#     'h7',
#     'h12',
#     'h19',
#     'h20',
#     'h3',
#     'h4',
#     'h13',
#     'h11',
#     'h10',
#     'h14',
#     'h16',
#     'h2'],
#    'f13': ['h5',
#     'h10',
#     'h17',
#     'h12',
#     'h6',
#     'h8',
#     'h20',
#     'h15',
#     'h2',
#     'h3',
#     'h19',
#     'h13',
#     'h9',
#     'h14',
#     'h7',
#     'h11',
#     'h18',
#     'h1',
#     'h16',
#     'h4'],
#    'f14': ['h20',
#     'h10',
#     'h11',
#     'h18',
#     'h6',
#     'h12',
#     'h17',
#     'h15',
#     'h16',
#     'h8',
#     'h3',
#     'h13',
#     'h2',
#     'h5',
#     'h1',
#     'h7',
#     'h19',
#     'h14',
#     'h4',
#     'h9'],
#    'f15': ['h12',
#     'h9',
#     'h14',
#     'h11',
#     'h2',
#     'h15',
#     'h4',
#     'h17',
#     'h3',
#     'h5',
#     'h16',
#     'h1',
#     'h18',
#     'h19',
#     'h8',
#     'h20',
#     'h6',
#     'h7',
#     'h10',
#     'h13'],
#    'f16': ['h2',
#     'h10',
#     'h6',
#     'h14',
#     'h7',
#     'h13',
#     'h11',
#     'h15',
#     'h16',
#     'h1',
#     'h12',
#     'h9',
#     'h8',
#     'h4',
#     'h17',
#     'h20',
#     'h18',
#     'h3',
#     'h19',
#     'h5'],
#    'f17': ['h7',
#     'h3',
#     'h6',
#     'h17',
#     'h2',
#     'h9',
#     'h8',
#     'h12',
#     'h10',
#     'h16',
#     'h19',
#     'h15',
#     'h11',
#     'h18',
#     'h13',
#     'h14',
#     'h20',
#     'h1',
#     'h5',
#     'h4'],
#    'f18': ['h5',
#     'h7',
#     'h15',
#     'h2',
#     'h9',
#     'h14',
#     'h8',
#     'h6',
#     'h12',
#     'h3',
#     'h4',
#     'h16',
#     'h19',
#     'h17',
#     'h20',
#     'h13',
#     'h18',
#     'h10',
#     'h11',
#     'h1'],
#    'f19': ['h12',
#     'h3',
#     'h19',
#     'h17',
#     'h7',
#     'h16',
#     'h20',
#     'h13',
#     'h1',
#     'h18',
#     'h11',
#     'h9',
#     'h14',
#     'h10',
#     'h6',
#     'h4',
#     'h5',
#     'h15',
#     'h8',
#     'h2'],
#    'f20': ['h8',
#     'h14',
#     'h12',
#     'h7',
#     'h3',
#     'h17',
#     'h6',
#     'h18',
#     'h4',
#     'h5',
#     'h9',
#     'h1',
#     'h16',
#     'h19',
#     'h15',
#     'h11',
#     'h20',
#     'h13',
#     'h10',
#     'h2'],
#    'h1': ['f10',
#     'f5',
#     'f9',
#     'f3',
#     'f8',
#     'f7',
#     'f13',
#     'f1',
#     'f17',
#     'f18',
#     'f15',
#     'f11',
#     'f6',
#     'f19',
#     'f4',
#     'f2',
#     'f20',
#     'f16',
#     'f12',
#     'f14'],
#    'h2': ['f3',
#     'f14',
#     'f17',
#     'f20',
#     'f7',
#     'f1',
#     'f9',
#     'f13',
#     'f10',
#     'f2',
#     'f18',
#     'f11',
#     'f6',
#     'f4',
#     'f16',
#     'f5',
#     'f12',
#     'f8',
#     'f15',
#     'f19'],
#    'h3': ['f15',
#     'f8',
#     'f17',
#     'f9',
#     'f11',
#     'f13',
#     'f14',
#     'f7',
#     'f6',
#     'f12',
#     'f1',
#     'f5',
#     'f19',
#     'f20',
#     'f18',
#     'f2',
#     'f10',
#     'f4',
#     'f3',
#     'f16'],
#    'h4': ['f11',
#     'f1',
#     'f6',
#     'f18',
#     'f19',
#     'f14',
#     'f3',
#     'f9',
#     'f16',
#     'f17',
#     'f4',
#     'f2',
#     'f8',
#     'f12',
#     'f13',
#     'f20',
#     'f5',
#     'f10',
#     'f15',
#     'f7'],
#    'h5': ['f12',
#     'f2',
#     'f5',
#     'f4',
#     'f19',
#     'f14',
#     'f17',
#     'f3',
#     'f7',
#     'f9',
#     'f10',
#     'f6',
#     'f15',
#     'f18',
#     'f13',
#     'f16',
#     'f1',
#     'f11',
#     'f8',
#     'f20'],
#    'h6': ['f20',
#     'f2',
#     'f8',
#     'f12',
#     'f4',
#     'f6',
#     'f18',
#     'f11',
#     'f5',
#     'f17',
#     'f13',
#     'f16',
#     'f19',
#     'f9',
#     'f1',
#     'f3',
#     'f10',
#     'f14',
#     'f7',
#     'f15'],
#    'h7': ['f16',
#     'f2',
#     'f17',
#     'f9',
#     'f1',
#     'f12',
#     'f15',
#     'f14',
#     'f7',
#     'f3',
#     'f5',
#     'f13',
#     'f11',
#     'f19',
#     'f6',
#     'f10',
#     'f20',
#     'f18',
#     'f4',
#     'f8'],
#    'h8': ['f2',
#     'f17',
#     'f8',
#     'f1',
#     'f10',
#     'f12',
#     'f20',
#     'f3',
#     'f19',
#     'f16',
#     'f15',
#     'f14',
#     'f13',
#     'f9',
#     'f11',
#     'f18',
#     'f5',
#     'f4',
#     'f7',
#     'f6'],
#    'h9': ['f9',
#     'f7',
#     'f1',
#     'f5',
#     'f10',
#     'f17',
#     'f3',
#     'f18',
#     'f15',
#     'f6',
#     'f11',
#     'f13',
#     'f16',
#     'f4',
#     'f14',
#     'f8',
#     'f19',
#     'f20',
#     'f2',
#     'f12'],
#    'h10': ['f16',
#     'f12',
#     'f14',
#     'f18',
#     'f20',
#     'f4',
#     'f1',
#     'f15',
#     'f19',
#     'f10',
#     'f7',
#     'f3',
#     'f6',
#     'f5',
#     'f2',
#     'f17',
#     'f9',
#     'f11',
#     'f13',
#     'f8'],
#    'h11': ['f2',
#     'f1',
#     'f3',
#     'f4',
#     'f7',
#     'f17',
#     'f20',
#     'f18',
#     'f11',
#     'f10',
#     'f13',
#     'f9',
#     'f8',
#     'f5',
#     'f12',
#     'f15',
#     'f16',
#     'f19',
#     'f14',
#     'f6'],
#    'h12': ['f16',
#     'f18',
#     'f8',
#     'f15',
#     'f12',
#     'f2',
#     'f4',
#     'f17',
#     'f13',
#     'f7',
#     'f19',
#     'f11',
#     'f6',
#     'f5',
#     'f10',
#     'f3',
#     'f14',
#     'f9',
#     'f20',
#     'f1'],
#    'h13': ['f7',
#     'f11',
#     'f19',
#     'f3',
#     'f20',
#     'f18',
#     'f8',
#     'f6',
#     'f1',
#     'f10',
#     'f13',
#     'f14',
#     'f17',
#     'f12',
#     'f4',
#     'f2',
#     'f15',
#     'f9',
#     'f16',
#     'f5'],
#    'h14': ['f5',
#     'f19',
#     'f18',
#     'f9',
#     'f13',
#     'f4',
#     'f1',
#     'f3',
#     'f2',
#     'f6',
#     'f15',
#     'f8',
#     'f17',
#     'f11',
#     'f12',
#     'f10',
#     'f20',
#     'f16',
#     'f14',
#     'f7'],
#    'h15': ['f17',
#     'f16',
#     'f5',
#     'f4',
#     'f2',
#     'f19',
#     'f1',
#     'f12',
#     'f3',
#     'f15',
#     'f6',
#     'f11',
#     'f13',
#     'f9',
#     'f8',
#     'f10',
#     'f7',
#     'f14',
#     'f18',
#     'f20'],
#    'h16': ['f1',
#     'f5',
#     'f16',
#     'f10',
#     'f18',
#     'f8',
#     'f19',
#     'f2',
#     'f3',
#     'f4',
#     'f7',
#     'f14',
#     'f17',
#     'f13',
#     'f20',
#     'f15',
#     'f11',
#     'f6',
#     'f9',
#     'f12'],
#    'h17': ['f11',
#     'f3',
#     'f17',
#     'f7',
#     'f5',
#     'f16',
#     'f12',
#     'f13',
#     'f4',
#     'f8',
#     'f2',
#     'f9',
#     'f19',
#     'f18',
#     'f20',
#     'f6',
#     'f10',
#     'f14',
#     'f15',
#     'f1'],
#    'h18': ['f17',
#     'f13',
#     'f2',
#     'f20',
#     'f1',
#     'f16',
#     'f8',
#     'f9',
#     'f4',
#     'f11',
#     'f5',
#     'f7',
#     'f15',
#     'f14',
#     'f6',
#     'f18',
#     'f19',
#     'f3',
#     'f12',
#     'f10'],
#    'h19': ['f5',
#     'f10',
#     'f14',
#     'f20',
#     'f1',
#     'f15',
#     'f18',
#     'f4',
#     'f9',
#     'f13',
#     'f3',
#     'f8',
#     'f17',
#     'f7',
#     'f16',
#     'f6',
#     'f2',
#     'f11',
#     'f12',
#     'f19'],
#    'h20': ['f20',
#     'f14',
#     'f13',
#     'f1',
#     'f3',
#     'f2',
#     'f8',
#     'f7',
#     'f12',
#     'f11',
#     'f15',
#     'f9',
#     'f17',
#     'f18',
#     'f5',
#     'f4',
#     'f10',
#     'f16',
#     'f19',
#     'f6']}),
#  (20,
#   2): (['f1',
#    'f2',
#    'f3',
#    'f4',
#    'f5',
#    'f6',
#    'f7',
#    'f8',
#    'f9',
#    'f10',
#    'f11',
#    'f12',
#    'f13',
#    'f14',
#    'f15',
#    'f16',
#    'f17',
#    'f18',
#    'f19',
#    'f20'], ['h1',
#    'h2',
#    'h3',
#    'h4',
#    'h5',
#    'h6',
#    'h7',
#    'h8',
#    'h9',
#    'h10',
#    'h11',
#    'h12',
#    'h13',
#    'h14',
#    'h15',
#    'h16',
#    'h17',
#    'h18',
#    'h19',
#    'h20'], {'f1': ['h20',
#     'h13',
#     'h15',
#     'h16',
#     'h12',
#     'h11',
#     'h10',
#     'h19',
#     'h5',
#     'h8',
#     'h17',
#     'h6',
#     'h7',
#     'h9',
#     'h1',
#     'h2',
#     'h4',
#     'h14',
#     'h3',
#     'h18'],
#    'f2': ['h2',
#     'h4',
#     'h9',
#     'h18',
#     'h5',
#     'h16',
#     'h11',
#     'h19',
#     'h12',
#     'h14',
#     'h15',
#     'h6',
#     'h13',
#     'h20',
#     'h3',
#     'h7',
#     'h10',
#     'h17',
#     'h8',
#     'h1'],
#    'f3': ['h10',
#     'h8',
#     'h5',
#     'h20',
#     'h14',
#     'h16',
#     'h1',
#     'h15',
#     'h13',
#     'h11',
#     'h9',
#     'h17',
#     'h4',
#     'h3',
#     'h19',
#     'h18',
#     'h12',
#     'h6',
#     'h2',
#     'h7'],
#    'f4': ['h6',
#     'h15',
#     'h4',
#     'h14',
#     'h8',
#     'h2',
#     'h19',
#     'h20',
#     'h7',
#     'h1',
#     'h3',
#     'h12',
#     'h16',
#     'h18',
#     'h10',
#     'h17',
#     'h13',
#     'h5',
#     'h11',
#     'h9'],
#    'f5': ['h16',
#     'h12',
#     'h18',
#     'h13',
#     'h3',
#     'h2',
#     'h9',
#     'h15',
#     'h10',
#     'h6',
#     'h20',
#     'h7',
#     'h8',
#     'h4',
#     'h14',
#     'h11',
#     'h1',
#     'h5',
#     'h19',
#     'h17'],
#    'f6': ['h19',
#     'h3',
#     'h17',
#     'h13',
#     'h12',
#     'h5',
#     'h20',
#     'h6',
#     'h15',
#     'h4',
#     'h8',
#     'h1',
#     'h7',
#     'h18',
#     'h14',
#     'h11',
#     'h9',
#     'h2',
#     'h10',
#     'h16'],
#    'f7': ['h1',
#     'h19',
#     'h8',
#     'h14',
#     'h4',
#     'h20',
#     'h18',
#     'h13',
#     'h12',
#     'h11',
#     'h2',
#     'h6',
#     'h16',
#     'h9',
#     'h7',
#     'h5',
#     'h17',
#     'h10',
#     'h3',
#     'h15'],
#    'f8': ['h2',
#     'h12',
#     'h7',
#     'h8',
#     'h3',
#     'h14',
#     'h15',
#     'h18',
#     'h17',
#     'h6',
#     'h1',
#     'h5',
#     'h13',
#     'h11',
#     'h10',
#     'h9',
#     'h19',
#     'h4',
#     'h16',
#     'h20'],
#    'f9': ['h13',
#     'h20',
#     'h5',
#     'h9',
#     'h1',
#     'h10',
#     'h16',
#     'h2',
#     'h14',
#     'h15',
#     'h3',
#     'h4',
#     'h18',
#     'h12',
#     'h19',
#     'h17',
#     'h11',
#     'h7',
#     'h8',
#     'h6'],
#    'f10': ['h12',
#     'h10',
#     'h2',
#     'h9',
#     'h7',
#     'h4',
#     'h1',
#     'h17',
#     'h11',
#     'h14',
#     'h5',
#     'h19',
#     'h3',
#     'h15',
#     'h20',
#     'h13',
#     'h6',
#     'h16',
#     'h8',
#     'h18'],
#    'f11': ['h16',
#     'h2',
#     'h10',
#     'h14',
#     'h6',
#     'h17',
#     'h20',
#     'h4',
#     'h11',
#     'h7',
#     'h9',
#     'h15',
#     'h1',
#     'h18',
#     'h13',
#     'h19',
#     'h12',
#     'h5',
#     'h3',
#     'h8'],
#    'f12': ['h1',
#     'h13',
#     'h20',
#     'h11',
#     'h17',
#     'h6',
#     'h5',
#     'h14',
#     'h8',
#     'h12',
#     'h10',
#     'h3',
#     'h2',
#     'h18',
#     'h19',
#     'h16',
#     'h15',
#     'h9',
#     'h4',
#     'h7'],
#    'f13': ['h6',
#     'h8',
#     'h14',
#     'h17',
#     'h10',
#     'h19',
#     'h5',
#     'h18',
#     'h12',
#     'h20',
#     'h4',
#     'h3',
#     'h15',
#     'h2',
#     'h11',
#     'h9',
#     'h16',
#     'h1',
#     'h7',
#     'h13'],
#    'f14': ['h11',
#     'h18',
#     'h19',
#     'h15',
#     'h7',
#     'h4',
#     'h6',
#     'h13',
#     'h12',
#     'h5',
#     'h16',
#     'h9',
#     'h1',
#     'h8',
#     'h17',
#     'h10',
#     'h3',
#     'h14',
#     'h2',
#     'h20'],
#    'f15': ['h10',
#     'h5',
#     'h18',
#     'h20',
#     'h13',
#     'h6',
#     'h16',
#     'h15',
#     'h1',
#     'h2',
#     'h7',
#     'h3',
#     'h9',
#     'h19',
#     'h12',
#     'h8',
#     'h17',
#     'h11',
#     'h4',
#     'h14'],
#    'f16': ['h10',
#     'h7',
#     'h8',
#     'h11',
#     'h15',
#     'h4',
#     'h6',
#     'h1',
#     'h5',
#     'h18',
#     'h2',
#     'h12',
#     'h9',
#     'h17',
#     'h13',
#     'h20',
#     'h3',
#     'h14',
#     'h19',
#     'h16'],
#    'f17': ['h3',
#     'h14',
#     'h19',
#     'h7',
#     'h1',
#     'h5',
#     'h12',
#     'h15',
#     'h17',
#     'h6',
#     'h11',
#     'h13',
#     'h9',
#     'h20',
#     'h8',
#     'h4',
#     'h18',
#     'h2',
#     'h10',
#     'h16'],
#    'f18': ['h18',
#     'h4',
#     'h10',
#     'h15',
#     'h6',
#     'h20',
#     'h14',
#     'h17',
#     'h16',
#     'h1',
#     'h12',
#     'h9',
#     'h13',
#     'h7',
#     'h5',
#     'h19',
#     'h3',
#     'h2',
#     'h8',
#     'h11'],
#    'f19': ['h1',
#     'h13',
#     'h10',
#     'h16',
#     'h20',
#     'h19',
#     'h3',
#     'h14',
#     'h2',
#     'h5',
#     'h18',
#     'h6',
#     'h8',
#     'h17',
#     'h9',
#     'h15',
#     'h11',
#     'h4',
#     'h12',
#     'h7'],
#    'f20': ['h2',
#     'h20',
#     'h7',
#     'h14',
#     'h5',
#     'h18',
#     'h15',
#     'h3',
#     'h17',
#     'h10',
#     'h1',
#     'h16',
#     'h6',
#     'h4',
#     'h12',
#     'h8',
#     'h19',
#     'h11',
#     'h9',
#     'h13'],
#    'h1': ['f1',
#     'f8',
#     'f5',
#     'f17',
#     'f14',
#     'f10',
#     'f4',
#     'f19',
#     'f16',
#     'f20',
#     'f11',
#     'f2',
#     'f13',
#     'f18',
#     'f15',
#     'f3',
#     'f7',
#     'f9',
#     'f6',
#     'f12'],
#    'h2': ['f15',
#     'f7',
#     'f13',
#     'f8',
#     'f9',
#     'f6',
#     'f11',
#     'f17',
#     'f14',
#     'f10',
#     'f18',
#     'f20',
#     'f4',
#     'f3',
#     'f12',
#     'f19',
#     'f16',
#     'f1',
#     'f2',
#     'f5'],
#    'h3': ['f3',
#     'f11',
#     'f13',
#     'f18',
#     'f20',
#     'f9',
#     'f15',
#     'f17',
#     'f5',
#     'f10',
#     'f12',
#     'f16',
#     'f1',
#     'f19',
#     'f4',
#     'f8',
#     'f7',
#     'f14',
#     'f2',
#     'f6'],
#    'h4': ['f17',
#     'f1',
#     'f15',
#     'f10',
#     'f12',
#     'f16',
#     'f11',
#     'f8',
#     'f18',
#     'f20',
#     'f9',
#     'f5',
#     'f14',
#     'f19',
#     'f7',
#     'f6',
#     'f13',
#     'f4',
#     'f3',
#     'f2'],
#    'h5': ['f4',
#     'f2',
#     'f5',
#     'f20',
#     'f14',
#     'f17',
#     'f9',
#     'f3',
#     'f18',
#     'f10',
#     'f7',
#     'f1',
#     'f19',
#     'f16',
#     'f6',
#     'f11',
#     'f12',
#     'f13',
#     'f8',
#     'f15'],
#    'h6': ['f16',
#     'f20',
#     'f4',
#     'f14',
#     'f7',
#     'f18',
#     'f15',
#     'f11',
#     'f2',
#     'f3',
#     'f8',
#     'f1',
#     'f5',
#     'f13',
#     'f12',
#     'f17',
#     'f19',
#     'f10',
#     'f9',
#     'f6'],
#    'h7': ['f12',
#     'f3',
#     'f6',
#     'f20',
#     'f2',
#     'f15',
#     'f7',
#     'f9',
#     'f5',
#     'f8',
#     'f16',
#     'f1',
#     'f17',
#     'f4',
#     'f18',
#     'f11',
#     'f19',
#     'f10',
#     'f14',
#     'f13'],
#    'h8': ['f9',
#     'f7',
#     'f3',
#     'f1',
#     'f10',
#     'f8',
#     'f4',
#     'f18',
#     'f17',
#     'f19',
#     'f2',
#     'f11',
#     'f15',
#     'f12',
#     'f13',
#     'f20',
#     'f16',
#     'f6',
#     'f5',
#     'f14'],
#    'h9': ['f2',
#     'f16',
#     'f10',
#     'f4',
#     'f9',
#     'f13',
#     'f8',
#     'f11',
#     'f3',
#     'f18',
#     'f15',
#     'f1',
#     'f5',
#     'f7',
#     'f12',
#     'f19',
#     'f20',
#     'f17',
#     'f6',
#     'f14'],
#    'h10': ['f17',
#     'f1',
#     'f15',
#     'f10',
#     'f7',
#     'f12',
#     'f18',
#     'f9',
#     'f16',
#     'f3',
#     'f6',
#     'f20',
#     'f13',
#     'f11',
#     'f4',
#     'f19',
#     'f5',
#     'f8',
#     'f2',
#     'f14'],
#    'h11': ['f8',
#     'f9',
#     'f14',
#     'f12',
#     'f19',
#     'f17',
#     'f13',
#     'f1',
#     'f10',
#     'f2',
#     'f6',
#     'f15',
#     'f16',
#     'f4',
#     'f5',
#     'f3',
#     'f18',
#     'f7',
#     'f11',
#     'f20'],
#    'h12': ['f13',
#     'f19',
#     'f3',
#     'f17',
#     'f8',
#     'f15',
#     'f16',
#     'f4',
#     'f2',
#     'f10',
#     'f9',
#     'f7',
#     'f12',
#     'f5',
#     'f18',
#     'f1',
#     'f20',
#     'f6',
#     'f11',
#     'f14'],
#    'h13': ['f8',
#     'f2',
#     'f13',
#     'f11',
#     'f12',
#     'f1',
#     'f7',
#     'f4',
#     'f6',
#     'f16',
#     'f5',
#     'f19',
#     'f14',
#     'f17',
#     'f18',
#     'f20',
#     'f3',
#     'f10',
#     'f15',
#     'f9'],
#    'h14': ['f13',
#     'f10',
#     'f11',
#     'f1',
#     'f20',
#     'f5',
#     'f3',
#     'f4',
#     'f18',
#     'f19',
#     'f17',
#     'f12',
#     'f8',
#     'f7',
#     'f9',
#     'f14',
#     'f2',
#     'f16',
#     'f15',
#     'f6'],
#    'h15': ['f5',
#     'f8',
#     'f9',
#     'f6',
#     'f14',
#     'f19',
#     'f11',
#     'f18',
#     'f2',
#     'f1',
#     'f12',
#     'f20',
#     'f7',
#     'f4',
#     'f13',
#     'f10',
#     'f17',
#     'f16',
#     'f15',
#     'f3'],
#    'h16': ['f19',
#     'f11',
#     'f7',
#     'f3',
#     'f16',
#     'f13',
#     'f18',
#     'f6',
#     'f8',
#     'f12',
#     'f17',
#     'f10',
#     'f4',
#     'f2',
#     'f5',
#     'f14',
#     'f15',
#     'f1',
#     'f20',
#     'f9'],
#    'h17': ['f12',
#     'f18',
#     'f11',
#     'f20',
#     'f3',
#     'f15',
#     'f2',
#     'f6',
#     'f9',
#     'f7',
#     'f10',
#     'f5',
#     'f8',
#     'f17',
#     'f19',
#     'f4',
#     'f1',
#     'f16',
#     'f13',
#     'f14'],
#    'h18': ['f3',
#     'f19',
#     'f2',
#     'f13',
#     'f9',
#     'f7',
#     'f17',
#     'f15',
#     'f6',
#     'f10',
#     'f12',
#     'f4',
#     'f11',
#     'f8',
#     'f20',
#     'f1',
#     'f5',
#     'f18',
#     'f14',
#     'f16'],
#    'h19': ['f4',
#     'f9',
#     'f10',
#     'f19',
#     'f14',
#     'f6',
#     'f3',
#     'f8',
#     'f11',
#     'f16',
#     'f13',
#     'f12',
#     'f5',
#     'f2',
#     'f1',
#     'f20',
#     'f7',
#     'f15',
#     'f18',
#     'f17'],
#    'h20': ['f3',
#     'f15',
#     'f17',
#     'f4',
#     'f19',
#     'f16',
#     'f20',
#     'f7',
#     'f14',
#     'f5',
#     'f2',
#     'f11',
#     'f18',
#     'f8',
#     'f13',
#     'f12',
#     'f9',
#     'f6',
#     'f1',
#     'f10']}),
#  (20,
#   3): (['f1',
#    'f2',
#    'f3',
#    'f4',
#    'f5',
#    'f6',
#    'f7',
#    'f8',
#    'f9',
#    'f10',
#    'f11',
#    'f12',
#    'f13',
#    'f14',
#    'f15',
#    'f16',
#    'f17',
#    'f18',
#    'f19',
#    'f20'], ['h1',
#    'h2',
#    'h3',
#    'h4',
#    'h5',
#    'h6',
#    'h7',
#    'h8',
#    'h9',
#    'h10',
#    'h11',
#    'h12',
#    'h13',
#    'h14',
#    'h15',
#    'h16',
#    'h17',
#    'h18',
#    'h19',
#    'h20'], {'f1': ['h9',
#     'h14',
#     'h18',
#     'h12',
#     'h17',
#     'h2',
#     'h7',
#     'h3',
#     'h19',
#     'h5',
#     'h8',
#     'h13',
#     'h10',
#     'h6',
#     'h20',
#     'h1',
#     'h11',
#     'h15',
#     'h16',
#     'h4'],
#    'f2': ['h12',
#     'h17',
#     'h14',
#     'h8',
#     'h13',
#     'h20',
#     'h11',
#     'h1',
#     'h16',
#     'h3',
#     'h4',
#     'h18',
#     'h9',
#     'h7',
#     'h10',
#     'h5',
#     'h2',
#     'h15',
#     'h6',
#     'h19'],
#    'f3': ['h10',
#     'h15',
#     'h12',
#     'h13',
#     'h20',
#     'h18',
#     'h16',
#     'h19',
#     'h1',
#     'h11',
#     'h2',
#     'h4',
#     'h6',
#     'h3',
#     'h14',
#     'h17',
#     'h9',
#     'h5',
#     'h8',
#     'h7'],
#    'f4': ['h5',
#     'h10',
#     'h4',
#     'h9',
#     'h18',
#     'h13',
#     'h15',
#     'h3',
#     'h2',
#     'h7',
#     'h6',
#     'h1',
#     'h16',
#     'h14',
#     'h19',
#     'h11',
#     'h17',
#     'h8',
#     'h12',
#     'h20'],
#    'f5': ['h15',
#     'h7',
#     'h1',
#     'h2',
#     'h12',
#     'h13',
#     'h18',
#     'h5',
#     'h19',
#     'h11',
#     'h14',
#     'h3',
#     'h10',
#     'h17',
#     'h4',
#     'h8',
#     'h6',
#     'h20',
#     'h9',
#     'h16'],
#    'f6': ['h12',
#     'h16',
#     'h14',
#     'h6',
#     'h7',
#     'h2',
#     'h11',
#     'h20',
#     'h9',
#     'h17',
#     'h1',
#     'h5',
#     'h15',
#     'h19',
#     'h3',
#     'h8',
#     'h13',
#     'h4',
#     'h18',
#     'h10'],
#    'f7': ['h15',
#     'h18',
#     'h11',
#     'h17',
#     'h7',
#     'h5',
#     'h8',
#     'h2',
#     'h12',
#     'h1',
#     'h19',
#     'h9',
#     'h14',
#     'h3',
#     'h16',
#     'h10',
#     'h13',
#     'h4',
#     'h6',
#     'h20'],
#    'f8': ['h7',
#     'h13',
#     'h15',
#     'h5',
#     'h2',
#     'h8',
#     'h1',
#     'h6',
#     'h19',
#     'h12',
#     'h16',
#     'h14',
#     'h11',
#     'h20',
#     'h4',
#     'h9',
#     'h18',
#     'h3',
#     'h17',
#     'h10'],
#    'f9': ['h5',
#     'h15',
#     'h2',
#     'h13',
#     'h3',
#     'h16',
#     'h6',
#     'h1',
#     'h17',
#     'h4',
#     'h20',
#     'h14',
#     'h7',
#     'h18',
#     'h9',
#     'h11',
#     'h10',
#     'h19',
#     'h12',
#     'h8'],
#    'f10': ['h6',
#     'h2',
#     'h15',
#     'h9',
#     'h7',
#     'h3',
#     'h19',
#     'h14',
#     'h4',
#     'h8',
#     'h16',
#     'h12',
#     'h5',
#     'h18',
#     'h11',
#     'h13',
#     'h17',
#     'h20',
#     'h10',
#     'h1'],
#    'f11': ['h12',
#     'h18',
#     'h17',
#     'h9',
#     'h14',
#     'h11',
#     'h16',
#     'h5',
#     'h4',
#     'h20',
#     'h8',
#     'h2',
#     'h1',
#     'h3',
#     'h6',
#     'h7',
#     'h13',
#     'h15',
#     'h10',
#     'h19'],
#    'f12': ['h14',
#     'h19',
#     'h12',
#     'h9',
#     'h11',
#     'h7',
#     'h18',
#     'h1',
#     'h20',
#     'h13',
#     'h6',
#     'h3',
#     'h8',
#     'h2',
#     'h17',
#     'h16',
#     'h10',
#     'h4',
#     'h5',
#     'h15'],
#    'f13': ['h9',
#     'h19',
#     'h14',
#     'h11',
#     'h8',
#     'h15',
#     'h7',
#     'h18',
#     'h16',
#     'h3',
#     'h20',
#     'h6',
#     'h2',
#     'h4',
#     'h1',
#     'h12',
#     'h17',
#     'h10',
#     'h13',
#     'h5'],
#    'f14': ['h17',
#     'h20',
#     'h9',
#     'h8',
#     'h5',
#     'h7',
#     'h12',
#     'h2',
#     'h19',
#     'h1',
#     'h10',
#     'h16',
#     'h11',
#     'h15',
#     'h14',
#     'h18',
#     'h6',
#     'h3',
#     'h13',
#     'h4'],
#    'f15': ['h14',
#     'h11',
#     'h6',
#     'h7',
#     'h16',
#     'h13',
#     'h3',
#     'h15',
#     'h12',
#     'h17',
#     'h10',
#     'h5',
#     'h2',
#     'h19',
#     'h1',
#     'h9',
#     'h8',
#     'h4',
#     'h18',
#     'h20'],
#    'f16': ['h9',
#     'h6',
#     'h12',
#     'h16',
#     'h3',
#     'h13',
#     'h18',
#     'h15',
#     'h19',
#     'h11',
#     'h14',
#     'h7',
#     'h20',
#     'h2',
#     'h1',
#     'h17',
#     'h5',
#     'h10',
#     'h8',
#     'h4'],
#    'f17': ['h19',
#     'h14',
#     'h8',
#     'h16',
#     'h20',
#     'h3',
#     'h2',
#     'h4',
#     'h13',
#     'h12',
#     'h1',
#     'h15',
#     'h9',
#     'h7',
#     'h18',
#     'h5',
#     'h11',
#     'h10',
#     'h6',
#     'h17'],
#    'f18': ['h12',
#     'h11',
#     'h10',
#     'h14',
#     'h15',
#     'h8',
#     'h16',
#     'h2',
#     'h1',
#     'h4',
#     'h9',
#     'h20',
#     'h19',
#     'h18',
#     'h3',
#     'h13',
#     'h6',
#     'h5',
#     'h7',
#     'h17'],
#    'f19': ['h4',
#     'h2',
#     'h20',
#     'h8',
#     'h6',
#     'h3',
#     'h15',
#     'h11',
#     'h1',
#     'h19',
#     'h14',
#     'h18',
#     'h13',
#     'h10',
#     'h7',
#     'h9',
#     'h12',
#     'h5',
#     'h17',
#     'h16'],
#    'f20': ['h20',
#     'h3',
#     'h9',
#     'h10',
#     'h13',
#     'h14',
#     'h16',
#     'h7',
#     'h17',
#     'h4',
#     'h11',
#     'h15',
#     'h8',
#     'h1',
#     'h12',
#     'h18',
#     'h19',
#     'h2',
#     'h5',
#     'h6'],
#    'h1': ['f17',
#     'f10',
#     'f19',
#     'f7',
#     'f2',
#     'f5',
#     'f9',
#     'f12',
#     'f18',
#     'f4',
#     'f3',
#     'f8',
#     'f16',
#     'f15',
#     'f11',
#     'f1',
#     'f13',
#     'f20',
#     'f14',
#     'f6'],
#    'h2': ['f14',
#     'f6',
#     'f18',
#     'f8',
#     'f20',
#     'f12',
#     'f5',
#     'f16',
#     'f7',
#     'f3',
#     'f19',
#     'f11',
#     'f13',
#     'f1',
#     'f17',
#     'f15',
#     'f9',
#     'f4',
#     'f2',
#     'f10'],
#    'h3': ['f9',
#     'f1',
#     'f5',
#     'f13',
#     'f20',
#     'f7',
#     'f12',
#     'f19',
#     'f11',
#     'f3',
#     'f2',
#     'f15',
#     'f18',
#     'f14',
#     'f10',
#     'f17',
#     'f8',
#     'f4',
#     'f6',
#     'f16'],
#    'h4': ['f11',
#     'f10',
#     'f5',
#     'f1',
#     'f19',
#     'f3',
#     'f14',
#     'f16',
#     'f8',
#     'f12',
#     'f9',
#     'f15',
#     'f13',
#     'f6',
#     'f4',
#     'f17',
#     'f2',
#     'f7',
#     'f20',
#     'f18'],
#    'h5': ['f5',
#     'f11',
#     'f16',
#     'f7',
#     'f10',
#     'f15',
#     'f9',
#     'f4',
#     'f8',
#     'f3',
#     'f17',
#     'f2',
#     'f12',
#     'f6',
#     'f20',
#     'f18',
#     'f14',
#     'f13',
#     'f1',
#     'f19'],
#    'h6': ['f6',
#     'f11',
#     'f10',
#     'f17',
#     'f8',
#     'f12',
#     'f16',
#     'f13',
#     'f5',
#     'f1',
#     'f15',
#     'f18',
#     'f20',
#     'f9',
#     'f7',
#     'f4',
#     'f2',
#     'f3',
#     'f19',
#     'f14'],
#    'h7': ['f5',
#     'f6',
#     'f10',
#     'f4',
#     'f18',
#     'f1',
#     'f20',
#     'f9',
#     'f3',
#     'f17',
#     'f12',
#     'f16',
#     'f7',
#     'f2',
#     'f8',
#     'f15',
#     'f13',
#     'f14',
#     'f19',
#     'f11'],
#    'h8': ['f9',
#     'f14',
#     'f17',
#     'f2',
#     'f18',
#     'f19',
#     'f7',
#     'f12',
#     'f8',
#     'f3',
#     'f13',
#     'f20',
#     'f15',
#     'f1',
#     'f4',
#     'f6',
#     'f10',
#     'f16',
#     'f11',
#     'f5'],
#    'h9': ['f18',
#     'f9',
#     'f14',
#     'f19',
#     'f10',
#     'f6',
#     'f17',
#     'f4',
#     'f16',
#     'f20',
#     'f5',
#     'f7',
#     'f13',
#     'f8',
#     'f2',
#     'f12',
#     'f11',
#     'f3',
#     'f1',
#     'f15'],
#    'h10': ['f7',
#     'f3',
#     'f11',
#     'f18',
#     'f17',
#     'f15',
#     'f13',
#     'f6',
#     'f5',
#     'f8',
#     'f20',
#     'f2',
#     'f12',
#     'f10',
#     'f9',
#     'f14',
#     'f4',
#     'f19',
#     'f16',
#     'f1'],
#    'h11': ['f19',
#     'f6',
#     'f14',
#     'f12',
#     'f3',
#     'f5',
#     'f20',
#     'f10',
#     'f1',
#     'f8',
#     'f9',
#     'f13',
#     'f17',
#     'f2',
#     'f4',
#     'f15',
#     'f11',
#     'f16',
#     'f18',
#     'f7'],
#    'h12': ['f17',
#     'f15',
#     'f4',
#     'f13',
#     'f12',
#     'f8',
#     'f18',
#     'f19',
#     'f6',
#     'f1',
#     'f20',
#     'f3',
#     'f11',
#     'f10',
#     'f2',
#     'f16',
#     'f7',
#     'f14',
#     'f9',
#     'f5'],
#    'h13': ['f15',
#     'f13',
#     'f8',
#     'f10',
#     'f20',
#     'f19',
#     'f18',
#     'f17',
#     'f6',
#     'f3',
#     'f2',
#     'f7',
#     'f11',
#     'f16',
#     'f4',
#     'f5',
#     'f12',
#     'f14',
#     'f1',
#     'f9'],
#    'h14': ['f19',
#     'f6',
#     'f9',
#     'f18',
#     'f16',
#     'f2',
#     'f8',
#     'f14',
#     'f4',
#     'f13',
#     'f11',
#     'f15',
#     'f3',
#     'f1',
#     'f7',
#     'f10',
#     'f12',
#     'f17',
#     'f5',
#     'f20'],
#    'h15': ['f13',
#     'f4',
#     'f19',
#     'f15',
#     'f18',
#     'f12',
#     'f6',
#     'f10',
#     'f17',
#     'f3',
#     'f7',
#     'f8',
#     'f5',
#     'f16',
#     'f14',
#     'f11',
#     'f9',
#     'f2',
#     'f1',
#     'f20'],
#    'h16': ['f12',
#     'f16',
#     'f19',
#     'f20',
#     'f17',
#     'f15',
#     'f8',
#     'f7',
#     'f3',
#     'f1',
#     'f10',
#     'f5',
#     'f18',
#     'f9',
#     'f13',
#     'f4',
#     'f14',
#     'f2',
#     'f6',
#     'f11'],
#    'h17': ['f10',
#     'f13',
#     'f8',
#     'f14',
#     'f4',
#     'f17',
#     'f19',
#     'f7',
#     'f2',
#     'f3',
#     'f6',
#     'f20',
#     'f5',
#     'f11',
#     'f18',
#     'f9',
#     'f12',
#     'f16',
#     'f15',
#     'f1'],
#    'h18': ['f20',
#     'f7',
#     'f9',
#     'f5',
#     'f18',
#     'f14',
#     'f10',
#     'f1',
#     'f15',
#     'f19',
#     'f3',
#     'f11',
#     'f17',
#     'f16',
#     'f2',
#     'f6',
#     'f4',
#     'f13',
#     'f12',
#     'f8'],
#    'h19': ['f1',
#     'f2',
#     'f5',
#     'f4',
#     'f13',
#     'f8',
#     'f20',
#     'f6',
#     'f11',
#     'f17',
#     'f14',
#     'f7',
#     'f16',
#     'f19',
#     'f18',
#     'f9',
#     'f12',
#     'f10',
#     'f15',
#     'f3'],
#    'h20': ['f13',
#     'f17',
#     'f2',
#     'f20',
#     'f15',
#     'f11',
#     'f12',
#     'f18',
#     'f14',
#     'f6',
#     'f9',
#     'f19',
#     'f1',
#     'f5',
#     'f8',
#     'f4',
#     'f7',
#     'f16',
#     'f3',
#     'f10']}),
#  (20,
#   4): (['f1',
#    'f2',
#    'f3',
#    'f4',
#    'f5',
#    'f6',
#    'f7',
#    'f8',
#    'f9',
#    'f10',
#    'f11',
#    'f12',
#    'f13',
#    'f14',
#    'f15',
#    'f16',
#    'f17',
#    'f18',
#    'f19',
#    'f20'], ['h1',
#    'h2',
#    'h3',
#    'h4',
#    'h5',
#    'h6',
#    'h7',
#    'h8',
#    'h9',
#    'h10',
#    'h11',
#    'h12',
#    'h13',
#    'h14',
#    'h15',
#    'h16',
#    'h17',
#    'h18',
#    'h19',
#    'h20'], {'f1': ['h16',
#     'h19',
#     'h4',
#     'h12',
#     'h18',
#     'h5',
#     'h3',
#     'h15',
#     'h2',
#     'h8',
#     'h1',
#     'h20',
#     'h6',
#     'h10',
#     'h13',
#     'h17',
#     'h7',
#     'h9',
#     'h11',
#     'h14'],
#    'f2': ['h16',
#     'h18',
#     'h1',
#     'h6',
#     'h9',
#     'h11',
#     'h4',
#     'h5',
#     'h10',
#     'h7',
#     'h15',
#     'h20',
#     'h8',
#     'h19',
#     'h3',
#     'h12',
#     'h17',
#     'h2',
#     'h13',
#     'h14'],
#    'f3': ['h9',
#     'h1',
#     'h17',
#     'h10',
#     'h4',
#     'h19',
#     'h6',
#     'h16',
#     'h3',
#     'h20',
#     'h2',
#     'h12',
#     'h15',
#     'h11',
#     'h18',
#     'h8',
#     'h13',
#     'h14',
#     'h5',
#     'h7'],
#    'f4': ['h13',
#     'h17',
#     'h12',
#     'h1',
#     'h11',
# ...
#     'h8',
#     'h29',
#     'h4',
#     'h18',
#     'h6',
#     'h3',
#     'h1',
#     'h2',
#     'h25',
#     'h30',
#     'h16',
#     'h13',
#     'h22',
#     'h5',
#     'h7',
#     'h26',
#     'h19',
#     'h21',
#     'h24',
#     'h10'],
#    'f13': ['h26',
#     'h15',
#     'h17',
#     'h2',
#     'h14',
#     'h3',
#     'h10',
#     'h24',
#     'h11',
#     'h6',
#     'h13',
#     'h1',
#     'h16',
#     'h28',
#     'h8',
#     'h22',
#     'h4',
#     'h25',
#     'h5',
#     'h12',
#     'h30',
#     'h9',
#     'h21',
#     'h23',
#     'h27',
#     'h18',
#     'h29',
#     'h20',
#     'h7',
#     'h19'],
#    'f14': ['h21',
#     'h30',
#     'h16',
#     'h6',
#     'h15',
#     'h17',
#     'h9',
#     'h8',
#     'h24',
#     'h26',
#     'h11',
#     'h25',
#     'h13',
#     'h10',
#     'h28',
#     'h23',
#     'h18',
#     'h12',
#     'h1',
#     'h22',
#     'h2',
#     'h5',
#     'h19',
#     'h3',
#     'h20',
#     'h4',
#     'h14',
#     'h7',
#     'h29',
#     'h27'],
#    'f15': ['h22',
#     'h21',
#     'h27',
#     'h10',
#     'h18',
#     'h25',
#     'h19',
#     'h28',
#     'h20',
#     'h23',
#     'h2',
#     'h12',
#     'h1',
#     'h17',
#     'h8',
#     'h13',
#     'h3',
#     'h16',
#     'h14',
#     'h6',
#     'h4',
#     'h5',
#     'h15',
#     'h26',
#     'h7',
#     'h9',
#     'h29',
#     'h30',
#     'h11',
#     'h24'],
#    'f16': ['h5',
#     'h10',
#     'h9',
#     'h19',
#     'h7',
#     'h22',
#     'h24',
#     'h8',
#     'h18',
#     'h27',
#     'h29',
#     'h4',
#     'h1',
#     'h16',
#     'h21',
#     'h12',
#     'h6',
#     'h20',
#     'h23',
#     'h30',
#     'h14',
#     'h3',
#     'h13',
#     'h15',
#     'h17',
#     'h26',
#     'h11',
#     'h25',
#     'h28',
#     'h2'],
#    'f17': ['h28',
#     'h11',
#     'h4',
#     'h14',
#     'h25',
#     'h15',
#     'h8',
#     'h23',
#     'h16',
#     'h7',
#     'h30',
#     'h3',
#     'h24',
#     'h29',
#     'h21',
#     'h26',
#     'h5',
#     'h17',
#     'h10',
#     'h22',
#     'h1',
#     'h12',
#     'h19',
#     'h20',
#     'h9',
#     'h27',
#     'h18',
#     'h2',
#     'h13',
#     'h6'],
#    'f18': ['h15',
#     'h7',
#     'h9',
#     'h23',
#     'h4',
#     'h1',
#     'h19',
#     'h24',
#     'h18',
#     'h3',
#     'h2',
#     'h12',
#     'h30',
#     'h5',
#     'h28',
#     'h10',
#     'h14',
#     'h25',
#     'h22',
#     'h16',
#     'h29',
#     'h6',
#     'h27',
#     'h13',
#     'h21',
#     'h26',
#     'h17',
#     'h8',
#     'h20',
#     'h11'],
#    'f19': ['h26',
#     'h3',
#     'h24',
#     'h27',
#     'h1',
#     'h14',
#     'h22',
#     'h12',
#     'h20',
#     'h21',
#     'h11',
#     'h29',
#     'h6',
#     'h5',
#     'h16',
#     'h17',
#     'h8',
#     'h7',
#     'h23',
#     'h30',
#     'h10',
#     'h2',
#     'h13',
#     'h18',
#     'h19',
#     'h15',
#     'h9',
#     'h28',
#     'h25',
#     'h4'],
#    'f20': ['h12',
#     'h14',
#     'h29',
#     'h5',
#     'h13',
#     'h1',
#     'h22',
#     'h7',
#     'h19',
#     'h15',
#     'h16',
#     'h10',
#     'h11',
#     'h26',
#     'h27',
#     'h28',
#     'h4',
#     'h20',
#     'h18',
#     'h25',
#     'h2',
#     'h9',
#     'h17',
#     'h24',
#     'h23',
#     'h8',
#     'h30',
#     'h21',
#     'h6',
#     'h3'],
#    'f21': ['h25',
#     'h1',
#     'h2',
#     'h18',
#     'h16',
#     'h30',
#     'h21',
#     'h8',
#     'h6',
#     'h10',
#     'h15',
#     'h9',
#     'h13',
#     'h14',
#     'h19',
#     'h26',
#     'h28',
#     'h11',
#     'h17',
#     'h20',
#     'h4',
#     'h12',
#     'h27',
#     'h22',
#     'h5',
#     'h29',
#     'h3',
#     'h23',
#     'h24',
#     'h7'],
#    'f22': ['h15',
#     'h17',
#     'h21',
#     'h20',
#     'h7',
#     'h25',
#     'h12',
#     'h1',
#     'h26',
#     'h8',
#     'h30',
#     'h28',
#     'h13',
#     'h5',
#     'h4',
#     'h6',
#     'h16',
#     'h3',
#     'h9',
#     'h10',
#     'h23',
#     'h19',
#     'h14',
#     'h27',
#     'h24',
#     'h18',
#     'h11',
#     'h22',
#     'h2',
#     'h29'],
#    'f23': ['h8',
#     'h14',
#     'h23',
#     'h20',
#     'h16',
#     'h7',
#     'h12',
#     'h1',
#     'h22',
#     'h3',
#     'h2',
#     'h26',
#     'h25',
#     'h5',
#     'h29',
#     'h10',
#     'h27',
#     'h4',
#     'h24',
#     'h6',
#     'h9',
#     'h30',
#     'h19',
#     'h13',
#     'h18',
#     'h17',
#     'h28',
#     'h15',
#     'h21',
#     'h11'],
#    'f24': ['h16',
#     'h14',
#     'h25',
#     'h4',
#     'h22',
#     'h7',
#     'h29',
#     'h23',
#     'h18',
#     'h30',
#     'h10',
#     'h17',
#     'h15',
#     'h2',
#     'h11',
#     'h12',
#     'h24',
#     'h28',
#     'h13',
#     'h9',
#     'h5',
#     'h21',
#     'h8',
#     'h6',
#     'h27',
#     'h26',
#     'h3',
#     'h20',
#     'h19',
#     'h1'],
#    'f25': ['h12',
#     'h3',
#     'h13',
#     'h10',
#     'h14',
#     'h7',
#     'h6',
#     'h17',
#     'h22',
#     'h8',
#     'h15',
#     'h28',
#     'h11',
#     'h4',
#     'h9',
#     'h19',
#     'h27',
#     'h2',
#     'h21',
#     'h16',
#     'h25',
#     'h5',
#     'h20',
#     'h26',
#     'h30',
#     'h18',
#     'h29',
#     'h1',
#     'h24',
#     'h23'],
#    'f26': ['h30',
#     'h15',
#     'h27',
#     'h6',
#     'h7',
#     'h19',
#     'h16',
#     'h24',
#     'h5',
#     'h28',
#     'h20',
#     'h22',
#     'h8',
#     'h14',
#     'h13',
#     'h18',
#     'h9',
#     'h26',
#     'h29',
#     'h11',
#     'h23',
#     'h3',
#     'h21',
#     'h1',
#     'h2',
#     'h10',
#     'h25',
#     'h12',
#     'h4',
#     'h17'],
#    'f27': ['h18',
#     'h15',
#     'h21',
#     'h20',
#     'h28',
#     'h5',
#     'h11',
#     'h29',
#     'h17',
#     'h30',
#     'h24',
#     'h2',
#     'h23',
#     'h25',
#     'h3',
#     'h27',
#     'h9',
#     'h13',
#     'h19',
#     'h14',
#     'h16',
#     'h4',
#     'h10',
#     'h7',
#     'h8',
#     'h26',
#     'h1',
#     'h12',
#     'h6',
#     'h22'],
#    'f28': ['h25',
#     'h26',
#     'h19',
#     'h5',
#     'h29',
#     'h12',
#     'h7',
#     'h24',
#     'h9',
#     'h20',
#     'h14',
#     'h30',
#     'h15',
#     'h21',
#     'h3',
#     'h17',
#     'h27',
#     'h18',
#     'h16',
#     'h13',
#     'h28',
#     'h10',
#     'h23',
#     'h8',
#     'h22',
#     'h2',
#     'h6',
#     'h11',
#     'h1',
#     'h4'],
#    'f29': ['h2',
#     'h28',
#     'h25',
#     'h15',
#     'h16',
#     'h17',
#     'h6',
#     'h13',
#     'h18',
#     'h3',
#     'h1',
#     'h29',
#     'h26',
#     'h10',
#     'h19',
#     'h11',
#     'h22',
#     'h4',
#     'h21',
#     'h30',
#     'h24',
#     'h20',
#     'h8',
#     'h12',
#     'h27',
#     'h23',
#     'h14',
#     'h9',
#     'h5',
#     'h7'],
#    'f30': ['h8',
#     'h16',
#     'h21',
#     'h23',
#     'h27',
#     'h28',
#     'h30',
#     'h5',
#     'h24',
#     'h29',
#     'h17',
#     'h11',
#     'h2',
#     'h4',
#     'h9',
#     'h19',
#     'h14',
#     'h26',
#     'h3',
#     'h25',
#     'h10',
#     'h20',
#     'h1',
#     'h13',
#     'h22',
#     'h6',
#     'h18',
#     'h15',
#     'h12',
#     'h7'],
#    'h1': ['f20',
#     'f15',
#     'f22',
#     'f24',
#     'f14',
#     'f17',
#     'f8',
#     'f16',
#     'f9',
#     'f23',
#     'f21',
#     'f26',
#     'f4',
#     'f28',
#     'f10',
#     'f2',
#     'f1',
#     'f12',
#     'f27',
#     'f6',
#     'f3',
#     'f25',
#     'f13',
#     'f5',
#     'f29',
#     'f19',
#     'f7',
#     'f11',
#     'f30',
#     'f18'],
#    'h2': ['f24',
#     'f21',
#     'f14',
#     'f29',
#     'f1',
#     'f18',
#     'f6',
#     'f20',
#     'f13',
#     'f5',
#     'f8',
#     'f10',
#     'f27',
#     'f22',
#     'f30',
#     'f15',
#     'f7',
#     'f23',
#     'f11',
#     'f19',
#     'f12',
#     'f16',
#     'f26',
#     'f17',
#     'f3',
#     'f25',
#     'f9',
#     'f4',
#     'f28',
#     'f2'],
#    'h3': ['f4',
#     'f18',
#     'f20',
#     'f1',
#     'f10',
#     'f11',
#     'f26',
#     'f25',
#     'f21',
#     'f22',
#     'f19',
#     'f24',
#     'f17',
#     'f9',
#     'f16',
#     'f8',
#     'f29',
#     'f28',
#     'f6',
#     'f23',
#     'f2',
#     'f15',
#     'f30',
#     'f27',
#     'f14',
#     'f3',
#     'f12',
#     'f13',
#     'f5',
#     'f7'],
#    'h4': ['f6',
#     'f26',
#     'f12',
#     'f13',
#     'f25',
#     'f30',
#     'f9',
#     'f21',
#     'f28',
#     'f11',
#     'f15',
#     'f2',
#     'f29',
#     'f10',
#     'f3',
#     'f4',
#     'f22',
#     'f16',
#     'f1',
#     'f23',
#     'f24',
#     'f27',
#     'f19',
#     'f20',
#     'f17',
#     'f14',
#     'f5',
#     'f8',
#     'f18',
#     'f7'],
#    'h5': ['f10',
#     'f26',
#     'f13',
#     'f2',
#     'f16',
#     'f27',
#     'f7',
#     'f28',
#     'f22',
#     'f11',
#     'f1',
#     'f4',
#     'f19',
#     'f23',
#     'f18',
#     'f3',
#     'f17',
#     'f29',
#     'f30',
#     'f9',
#     'f5',
#     'f20',
#     'f14',
#     'f6',
#     'f15',
#     'f12',
#     'f8',
#     'f24',
#     'f25',
#     'f21'],
#    'h6': ['f9',
#     'f5',
#     'f29',
#     'f17',
#     'f8',
#     'f28',
#     'f19',
#     'f7',
#     'f12',
#     'f16',
#     'f10',
#     'f4',
#     'f2',
#     'f15',
#     'f1',
#     'f13',
#     'f21',
#     'f26',
#     'f22',
#     'f24',
#     'f14',
#     'f11',
#     'f18',
#     'f23',
#     'f25',
#     'f3',
#     'f20',
#     'f6',
#     'f30',
#     'f27'],
#    'h7': ['f30',
#     'f12',
#     'f13',
#     'f8',
#     'f3',
#     'f15',
#     'f4',
#     'f21',
#     'f22',
#     'f17',
#     'f10',
#     'f25',
#     'f1',
#     'f28',
#     'f7',
#     'f20',
#     'f16',
#     'f27',
#     'f29',
#     'f23',
#     'f9',
#     'f19',
#     'f14',
#     'f11',
#     'f6',
#     'f2',
#     'f24',
#     'f26',
#     'f18',
#     'f5'],
#    'h8': ['f28',
#     'f11',
#     'f1',
#     'f20',
#     'f18',
#     'f12',
#     'f30',
#     'f3',
#     'f19',
#     'f5',
#     'f13',
#     'f22',
#     'f8',
#     'f15',
#     'f16',
#     'f23',
#     'f14',
#     'f24',
#     'f10',
#     'f2',
#     'f26',
#     'f9',
#     'f17',
#     'f7',
#     'f25',
#     'f29',
#     'f21',
#     'f6',
#     'f4',
#     'f27'],
#    'h9': ['f8',
#     'f28',
#     'f20',
#     'f15',
#     'f26',
#     'f25',
#     'f6',
#     'f16',
#     'f30',
#     'f12',
#     'f21',
#     'f4',
#     'f14',
#     'f17',
#     'f2',
#     'f7',
#     'f18',
#     'f19',
#     'f1',
#     'f5',
#     'f11',
#     'f9',
#     'f27',
#     'f22',
#     'f13',
#     'f23',
#     'f3',
#     'f29',
#     'f24',
#     'f10'],
#    'h10': ['f26',
#     'f25',
#     'f2',
#     'f10',
#     'f7',
#     'f18',
#     'f5',
#     'f22',
#     'f24',
#     'f27',
#     'f15',
#     'f4',
#     'f19',
#     'f8',
#     'f17',
#     'f16',
#     'f12',
#     'f29',
#     'f3',
#     'f28',
#     'f13',
#     'f30',
#     'f11',
#     'f9',
#     'f14',
#     'f6',
#     'f23',
#     'f1',
#     'f21',
#     'f20'],
#    'h11': ['f24',
#     'f16',
#     'f1',
#     'f18',
#     'f2',
#     'f13',
#     'f7',
#     'f12',
#     'f20',
#     'f21',
#     'f23',
#     'f4',
#     'f25',
#     'f30',
#     'f14',
#     'f15',
#     'f29',
#     'f6',
#     'f19',
#     'f26',
#     'f17',
#     'f11',
#     'f8',
#     'f22',
#     'f10',
#     'f5',
#     'f9',
#     'f27',
#     'f28',
#     'f3'],
#    'h12': ['f3',
#     'f5',
#     'f14',
#     'f18',
#     'f2',
#     'f9',
#     'f6',
#     'f16',
#     'f15',
#     'f17',
#     'f10',
#     'f29',
#     'f19',
#     'f25',
#     'f12',
#     'f28',
#     'f23',
#     'f20',
#     'f7',
#     'f22',
#     'f1',
#     'f11',
#     'f13',
#     'f8',
#     'f30',
#     'f27',
#     'f4',
#     'f26',
#     'f21',
#     'f24'],
#    'h13': ['f11',
#     'f28',
#     'f3',
#     'f5',
#     'f1',
#     'f13',
#     'f29',
#     'f30',
#     'f7',
#     'f9',
#     'f14',
#     'f6',
#     'f25',
#     'f18',
#     'f17',
#     'f2',
#     'f27',
#     'f19',
#     'f4',
#     'f10',
#     'f12',
#     'f8',
#     'f23',
#     'f15',
#     'f24',
#     'f21',
#     'f26',
#     'f22',
#     'f20',
#     'f16'],
#    'h14': ['f17',
#     'f19',
#     'f14',
#     'f4',
#     'f24',
#     'f5',
#     'f20',
#     'f23',
#     'f29',
#     'f15',
#     'f27',
#     'f22',
#     'f8',
#     'f2',
#     'f21',
#     'f6',
#     'f7',
#     'f25',
#     'f10',
#     'f16',
#     'f18',
#     'f11',
#     'f28',
#     'f30',
#     'f1',
#     'f9',
#     'f13',
#     'f12',
#     'f3',
#     'f26'],
#    'h15': ['f4',
#     'f30',
#     'f29',
#     'f11',
#     'f23',
#     'f13',
#     'f16',
#     'f3',
#     'f9',
#     'f15',
#     'f12',
#     'f18',
#     'f27',
#     'f17',
#     'f26',
#     'f1',
#     'f20',
#     'f21',
#     'f19',
#     'f7',
#     'f2',
#     'f22',
#     'f5',
#     'f28',
#     'f6',
#     'f10',
#     'f24',
#     'f8',
#     'f25',
#     'f14'],
#    'h16': ['f30',
#     'f11',
#     'f12',
#     'f29',
#     'f1',
#     'f2',
#     'f26',
#     'f23',
#     'f3',
#     'f16',
#     'f17',
#     'f8',
#     'f22',
#     'f6',
#     'f21',
#     'f10',
#     'f7',
#     'f9',
#     'f20',
#     'f27',
#     'f14',
#     'f18',
#     'f5',
#     'f13',
#     'f25',
#     'f28',
#     'f4',
#     'f24',
#     'f19',
#     'f15'],
#    'h17': ['f7',
#     'f25',
#     'f5',
#     'f13',
#     'f30',
#     'f18',
#     'f6',
#     'f16',
#     'f12',
#     'f4',
#     'f8',
#     'f3',
#     'f24',
#     'f20',
#     'f14',
#     'f29',
#     'f19',
#     'f27',
#     'f9',
#     'f15',
#     'f2',
#     'f22',
#     'f10',
#     'f21',
#     'f23',
#     'f11',
#     'f28',
#     'f17',
#     'f1',
#     'f26'],
#    'h18': ['f3',
#     'f25',
#     'f17',
#     'f7',
#     'f28',
#     'f29',
#     'f10',
#     'f18',
#     'f20',
#     'f12',
#     'f19',
#     'f1',
#     'f13',
#     'f14',
#     'f6',
#     'f23',
#     'f15',
#     'f8',
#     'f5',
#     'f30',
#     'f26',
#     'f27',
#     'f4',
#     'f22',
#     'f2',
#     'f11',
#     'f21',
#     'f24',
#     'f16',
#     'f9'],
#    'h19': ['f11',
#     'f19',
#     'f27',
#     'f18',
#     'f29',
#     'f25',
#     'f9',
#     'f3',
#     'f15',
#     'f24',
#     'f20',
#     'f2',
#     'f17',
#     'f16',
#     'f10',
#     'f7',
#     'f6',
#     'f21',
#     'f12',
#     'f5',
#     'f14',
#     'f8',
#     'f1',
#     'f22',
#     'f30',
#     'f23',
#     'f4',
#     'f26',
#     'f13',
#     'f28'],
#    'h20': ['f13',
#     'f14',
#     'f21',
#     'f9',
#     'f24',
#     'f17',
#     'f26',
#     'f25',
#     'f28',
#     'f2',
#     'f6',
#     'f19',
#     'f22',
#     'f15',
#     'f27',
#     'f10',
#     'f29',
#     'f1',
#     'f4',
#     'f16',
#     'f8',
#     'f3',
#     'f23',
#     'f20',
#     'f7',
#     'f30',
#     'f5',
#     'f12',
#     'f11',
#     'f18'],
#    'h21': ['f25',
#     'f27',
#     'f7',
#     'f23',
#     'f18',
#     'f28',
#     'f9',
#     'f3',
#     'f4',
#     'f19',
#     'f14',
#     'f2',
#     'f29',
#     'f20',
#     'f13',
#     'f30',
#     'f6',
#     'f5',
#     'f11',
#     'f21',
#     'f16',
#     'f17',
#     'f1',
#     'f10',
#     'f8',
#     'f15',
#     'f12',
#     'f22',
#     'f26',
#     'f24'],
#    'h22': ['f17',
#     'f23',
#     'f6',
#     'f16',
#     'f30',
#     'f10',
#     'f20',
#     'f21',
#     'f13',
#     'f11',
#     'f15',
#     'f7',
#     'f12',
#     'f24',
#     'f9',
#     'f5',
#     'f8',
#     'f25',
#     'f29',
#     'f19',
#     'f22',
#     'f27',
#     'f14',
#     'f18',
#     'f1',
#     'f3',
#     'f28',
#     'f4',
#     'f2',
#     'f26'],
#    'h23': ['f4',
#     'f17',
#     'f15',
#     'f8',
#     'f22',
#     'f12',
#     'f26',
#     'f29',
#     'f24',
#     'f28',
#     'f14',
#     'f5',
#     'f16',
#     'f19',
#     'f1',
#     'f20',
#     'f3',
#     'f11',
#     'f2',
#     'f9',
#     'f27',
#     'f10',
#     'f13',
#     'f18',
#     'f23',
#     'f21',
#     'f7',
#     'f30',
#     'f6',
#     'f25'],
#    'h24': ['f24',
#     'f30',
#     'f12',
#     'f2',
#     'f4',
#     'f25',
#     'f9',
#     'f16',
#     'f21',
#     'f7',
#     'f18',
#     'f20',
#     'f8',
#     'f1',
#     'f11',
#     'f27',
#     'f29',
#     'f13',
#     'f14',
#     'f28',
#     'f10',
#     'f23',
#     'f5',
#     'f17',
#     'f26',
#     'f15',
#     'f19',
#     'f22',
#     'f3',
#     'f6'],
#    'h25': ['f6',
#     'f24',
#     'f19',
#     'f17',
#     'f4',
#     'f23',
#     'f2',
#     'f8',
#     'f12',
#     'f1',
#     'f22',
#     'f9',
#     'f13',
#     'f30',
#     'f29',
#     'f18',
#     'f28',
#     'f25',
#     'f15',
#     'f11',
#     'f3',
#     'f20',
#     'f5',
#     'f26',
#     'f14',
#     'f7',
#     'f21',
#     'f27',
#     'f10',
#     'f16'],
#    'h26': ['f29',
#     'f19',
#     'f30',
#     'f5',
#     'f15',
#     'f10',
#     'f3',
#     'f26',
#     'f11',
#     'f8',
#     'f28',
#     'f25',
#     'f16',
#     'f4',
#     'f7',
#     'f27',
#     'f2',
#     'f24',
#     'f18',
#     'f20',
#     'f22',
#     'f12',
#     'f17',
#     'f1',
#     'f9',
#     'f21',
#     'f23',
#     'f14',
#     'f6',
#     'f13'],
#    'h27': ['f27',
#     'f29',
#     'f7',
#     'f2',
#     'f19',
#     'f30',
#     'f3',
#     'f13',
#     'f6',
#     'f24',
#     'f5',
#     'f14',
#     'f11',
#     'f15',
#     'f16',
#     'f12',
#     'f22',
#     'f20',
#     'f26',
#     'f10',
#     'f9',
#     'f28',
#     'f4',
#     'f17',
#     'f25',
#     'f1',
#     'f18',
#     'f8',
#     'f21',
#     'f23'],
#    'h28': ['f2',
#     'f15',
#     'f27',
#     'f18',
#     'f25',
#     'f8',
#     'f9',
#     'f20',
#     'f22',
#     'f12',
#     'f5',
#     'f26',
#     'f1',
#     'f21',
#     'f16',
#     'f6',
#     'f14',
#     'f13',
#     'f23',
#     'f3',
#     'f4',
#     'f29',
#     'f24',
#     'f30',
#     'f17',
#     'f19',
#     'f7',
#     'f10',
#     'f28',
#     'f11'],
#    'h29': ['f3',
#     'f7',
#     'f8',
#     'f9',
#     'f13',
#     'f27',
#     'f12',
#     'f21',
#     'f4',
#     'f30',
#     'f16',
#     'f14',
#     'f6',
#     'f29',
#     'f20',
#     'f22',
#     'f26',
#     'f5',
#     'f10',
#     'f15',
#     'f19',
#     'f28',
#     'f23',
#     'f24',
#     'f11',
#     'f25',
#     'f17',
#     'f2',
#     'f18',
#     'f1'],
#    'h30': ['f20',
#     'f9',
#     'f1',
#     'f22',
#     'f8',
#     'f26',
#     'f30',
#     'f25',
#     'f3',
#     'f27',
#     'f4',
#     'f11',
#     'f24',
#     'f2',
#     'f29',
#     'f17',
#     'f23',
#     'f12',
#     'f15',
#     'f21',
#     'f5',
#     'f6',
#     'f18',
#     'f13',
#     'f19',
#     'f7',
#     'f14',
#     'f16',
#     'f10',
#     'f28']})}

# %%
def run_and_display(S,type,H,F,L):
    mdl = CpoModel(name="Mariages "+type)
    mdl.set_search_phases(S)
    
for N in  [5,10,20,30]:
    for I in  range(0,5):
        H, F, L=create_random_problem(N)

# %%
def add_equity_constraint(mdl,D,H,F):
    DH = mdl.integer_var(name="DH")
    DF = mdl.integer_var(name="DF")

    mdl.add(DH==max([D[h] for h in H]))
    mdl.add(DF==max([D[f] for f in F]))
    mdl.add(minimize(abs(DH-DF)))

    return DH,DF

# %%
def print_equity_solution(solution,x,D,DH,DF):
    print_solution(solution,x,D)
    print("\nDF = ",solution[DF])
    print("DH = ",solution[DH])

# %%
DH, DF = add_equity_constraint(mdl,D,H,F)
solution = mdl.solve(trace_log=False)
print_equity_solution(solution,x,D,DH,DF)
# Out:
#    SOLUTION :
#
# Mariage entre  h1  et  f1  (Couts =  1 2 )
# Mariage entre  h2  et  f18  (Couts =  4 5 )
# Mariage entre  h3  et  f20  (Couts =  2 1 )
# Mariage entre  h4  et  f19  (Couts =  0 3 )
# Mariage entre  h5  et  f4  (Couts =  1 0 )
# Mariage entre  h6  et  f8  (Couts =  12 1 )
# Mariage entre  h7  et  f9  (Couts =  2 6 )
# Mariage entre  h8  et  f16  (Couts =  1 7 )
# Mariage entre  h9  et  f6  (Couts =  0 0 )
# Mariage entre  h10  et  f13  (Couts =  5 0 )
# Mariage entre  h11  et  f7  (Couts =  3 2 )
# Mariage entre  h12  et  f12  (Couts =  1 0 )
# Mariage entre  h13  et  f11  (Couts =  9 2 )
# Mariage entre  h14  et  f15  (Couts =  0 0 )
# Mariage entre  h15  et  f3  (Couts =  4 5 )
# Mariage entre  h16  et  f2  (Couts =  8 3 )
# Mariage entre  h17  et  f5  (Couts =  5 13 )
# Mariage entre  h18  et  f17  (Couts =  6 3 )
# Mariage entre  h19  et  f10  (Couts =  6 7 )
# Mariage entre  h20  et  f14  (Couts =  0 1 )
#
# DF =  13
# DH =  12
